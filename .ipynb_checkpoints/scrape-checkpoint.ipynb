# %% [markdown]
# ### RateBeer.com Scrape Scrape Scrape

# %%
import requests
import sqlalchemy
import pandas as pd
import numpy as np 
import urllib.request
from bs4 import BeautifulSoup
import re
import csv
import unicodedata
import itertools

# %%
response = requests.get('https://www.ratebeer.com/beer-ratings/')

# %%
# response.content #test it on the content

# %%
#lets get text instead of bytes
# response.text

# %%
response.headers
# Out:
# {'Date': 'Fri, 07 Feb 2020 02:17:45 GMT', 'Content-Type': 'text/html;charset=UTF-8,text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=d5bcaeb37f07eb7363530911c1d34bcde1581041865; expires=Sun, 08-Mar-20 02:17:45 GMT; path=/; domain=.ratebeer.com; HttpOnly; SameSite=Lax; Secure, legacy_session=SCDQTSDQ/OAKHJMACAAIAJKKBCAFLDEPC; path=/; HttpOnly', 'Cache-Control': 'private', 'X-Powered-By': 'ASP.NET', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; mode=block', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '5611de8b0b502184-EWR', 'Content-Encoding': 'gzip'}

# %%
response.headers['Content-Type']
# Out:
# 'text/html;charset=UTF-8,text/html;charset=UTF-8'

# %%
# url = response.request.url

# %% [markdown]
# ### Make it prettier to read

# %% [markdown]
# <a id='Pretty_Tree'></a>

# %%
URL = 'https://www.ratebeer.com/beer-ratings/'
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
#   <title>
#    Beer Reviews - The latest beer reviews - Most Recent
#   </title>
#   <meta content="The latest beer reviews from RateBeer, the largest collection of beer reviews in the world." name="description"/>
#   <meta content="beer, beer reviews, ratebeer, craft beer" name="keywords"/>
#   <link href="/css/inc_bubbles.css" rel="stylesheet" type="text/css"/>
#   <link href="/tags/tags.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/jquery-ui-1.9.2.custom.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/brewer_tooltip.css" rel="stylesheet" type="text/css"/>
#   <!-- Optimize displays variants to your website visitors
# by modifying the DOM (Document Object Model).
# In some instances, changes are made to elements that
# are already visible to the end user.
# These visible changes are referred to as page flicker.
#
# One of the most effective ways to mitigate the risk
# of page flicker when loading Optimize is to temporarily
# hide the page while the Optimize container loads.
# This can be accomplished by adding the page-hiding snippet
# as the first script on your page(s) – after the <meta charset>
# declarations and before your Optimize, Analytics and/or Tag Manager tags.
#
# GTM-K6BZD7 is our TGM web container id -->
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);
# })(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-K6BZD7':true});
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6BZD7');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script type="text/javascript">
#    window.siteURL='https://www.ratebeer.com';window.auth0ClientID='vy3vQxKFXvMyXTjddkMiDJAUFucb8vdu';
#   </script>
#   <meta content="EN" http-equiv="content-language"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="general" name="rating"/>
#   <meta content="RateBeer" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://s3-us-west-2.amazonaws.com/ratebeer-mobile-app-bucket/RateBeerAppLogo.png" property="og:image"/>
#   <meta content="13411472" property="twitter:account_id"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
#   <meta content="@ratebeer" name="twitter:site"/>
#   <meta content="@ratebeer" name="twitter:creator"/>
#   <meta content="https://www.ratebeer.com" name="twitter:domain"/>
#   <!-- JS Global Compulsory, 2nd -->
#   <script src="//code.jquery.com/jquery-2.2.4.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-0mSbJDEHialfmuBBQP6A4Qrprq5OVfW37PRR3j5ELqxss1yVqOtnepnHVP9aJ7xS" src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.6/js/bootstrap.min.js">
#   </script>
#   <!-- Latest compiled and minified CSS, 1st -->
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css" integrity="sha384-1q8mTJOASx8j1Au+a5WDVnPi2lkFfwwEAa8hDDdjZlpLegxhjVME1fgjWPGmkzs7" rel="stylesheet"/>
#   <link href="/css/custombs.css" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Fira+Sans:700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto" rel="stylesheet"/>
#   <script src="/js/ihavecookies.js">
#   </script>
#   <script async="async" src="//www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
#    // Define a size mapping object. The first parameter to addSize is
# // a viewport size, while the second is a list of allowed ad sizes.
#
# googletag.cmd.push(function() {
#    var mapping = googletag.sizeMapping().
#   addSize([1280, 0], [[970, 90], [728, 90], [468, 60], [300, 250]]).
# //desktop big
#   addSize([1024, 0], [[970, 90], [728, 90], [468, 60], [250, 250], [200,
# 200]]). //desktop
#   addSize([768, 0], [[728, 90], [468, 60]]). //laptop
#   addSize([480, 0], [468, 60]). //tablet
#   addSize([420, 0], [320, 50]). //tablet
#   addSize([0, 0], [[320, 50]]). //others
#   build();
#
# // Define the GPT slot
#
#     googletag.defineSlot('/3397136/Large-Leaderboard-GPT', [970, 90],
# 'div-gpt-ad-1474465396265-0').defineSizeMapping(mapping).addService(googletag.pubads());
#     googletag.defineSlot('/3397136/GPT-Medium-Rectangle', [[250, 250],
# [300, 250], [200, 200]],
# 'div-gpt-ad-1474477890595-0').addService(googletag.pubads());
#     googletag.defineSlot('/3397136/GPT-Low-Leaderboard', [970,
# 90], 'div-gpt-ad-1474478067303-1').defineSizeMapping(mapping).addService(googletag.pubads());
#
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().setTargeting("test","responsive");
# // Start ad fetching
#    googletag.enableServices();
#  });
#   </script>
#   <style>
#    #html * {   font-family: 'Roboto', sans-serif;}
# h1, h3{font-family: 'Fira Sans', sans-serif !important; margin-bottom: 2px;}
#
# /* reset webkit search input browser style */
# input {
# 	outline: none;
# }
# input[type=search] {
# 	-webkit-appearance: textfield;
# 	-webkit-box-sizing: content-box;
# 	font-family: inherit;
# 	font-size: 100%;
# }
# input::-webkit-search-decoration,
# input::-webkit-search-cancel-button {
# 	display: none; /* remove the search and cancel icon */
# }
#
# /* search input field */
# input[type=search] {
# 	background: #ededed;
# 	border: solid 1px #ccc;
# 	padding: 9px 10px 9px 10px;
# 	width: 95px;
#
# 	-webkit-border-radius: 10em;
# 	-moz-border-radius: 10em;
# 	border-radius: 10em;
#
# 	-webkit-transition: all .3s;
# 	-moz-transition: all .3s;
# 	transition: all .3s;
# }
# input[type=search]:focus {
# 	width: 85%;
# 	background-color: #fff;
# 	border-color: #6dcff6;
#
# 	-webkit-box-shadow: 0 0 5px rgba(109,207,246,.5);
# 	-moz-box-shadow: 0 0 5px rgba(109,207,246,.5);
# 	box-shadow: 0 0 5px rgba(109,207,246,.5);
# }
#
# /* placeholder */
# input:-moz-placeholder {
# 	color: #999;
# }
# input::-webkit-input-placeholder {
# 	color: #999;
# }
# .norman {margin-top: 8px; margin-bottom: 8px; margin-right: 3px;}
#
# #rbbody{max-width: 1600px; margin: auto;}
# #.rblogo {max-height:48px; margin: 10px 0px 10px 20px;border:0;}
# .logo {margin: 10px 0px 0px 20px;border:0;}
# .mobile-nav-menu{position: absolute; right: 0;text-align:right;}
# #.browser-nav-menu{padding-right:40px;}
# .header-leaderboard{border: 1px solid #e0e0e0; width: 100%; margin: auto; text-align: center; white-space:nowrap;min-height: 60px;margin: 0px 0px 10px 0px;}
#
#  /* Cookie Dialog */
#     #gdpr-cookie-message {
#         position: fixed;
#         right: 30px;
#         bottom: 30px;
#         max-width: 375px;
#         background-color: #e0e0e0;
#         padding: 20px;
#         border-radius: 5px;
#         box-shadow: 0 6px 6px rgba(0,0,0,0.25);
#         margin-left: 30px;
#         font-family: system-ui;
#     }
#     #gdpr-cookie-message h4 {
#         color: #1f8cbb;
#         font-family: 'Roboto', sans-serif;
#         font-size: 18px;
#         font-weight: 500;
#         margin-bottom: 10px;
#     }
#     #gdpr-cookie-message p {
#         color: #333333;
#         font-size: 15px;
#         line-height: 1.5em;
#     }
#     #gdpr-cookie-message p:last-child {
#         margin-bottom: 0;
#         text-align: right;
#     }
#     #gdpr-cookie-message a {
#         color: #;
#         text-decoration: none;
#         font-size: 15px;
#         padding-bottom: 2px;
#         border-bottom: 1px dotted rgba(255,255,255,0.75);
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message a:hover {
#         color: #e0e0e0;
#         border-bottom-color: var(--blue);
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message button {
#         border: none;
#         background: #1f8cbb;
#         color: white;
#         font-family: 'Roboto', sans-serif;
#         font-size: 15px;
#         padding: 7px;
#         border-radius: 3px;
#         margin-left: 15px;
#         cursor: pointer;
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message button:hover {
#         background: #1f8cbb;
#         color: #ffffff;
#         transition: all 0.3s ease-in;
#     }
#   </style>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 	$('body').ihavecookies({
#   title: "Cookies & Privacy",
#   message: "We use cookies to offer you a better browsing experience. This website can only display its content once you accept the sites cookies. Additionally, we use tracking technologies to analyze your use of this website, to deliver advertisements tailored to your interests by cooperating with ad networks, ad serving vendors and similar services. We may collect information about your online activity (e.g., the sites and pages you have visited) through tracking technologies such as cookies, tracking pixels and similar devices in order to deliver ads and online services that are relevant to you.",
#   expires: 365 // 365 days
#         });
#     });
#   </script>
#  </head>
#  <body>
#   <div id="rbbody">
#    <!--
# <div class="container">
#     <div class="col-xs-12 col-xl-12 alert alert-danger">
#         RateBeer is scheduled for maintainence from <b>08:00 UTC - 09:00 UTC</b>
#     </div>
# </div>
# -->
#    <div class="row" style="margin-left: 0; margin-right: 0;">
#     <div class="col-xs-4 col-sm-4 col-md-4 col-lg-3">
#      <a href="/">
#       <img alt="RateBeer" class="img-responsive rblogo" height="38" src="/images/logos/rblogo0316.png" width="160"/>
#      </a>
#     </div>
#     <div class="col-xs-4 col-sm-5 col-md-4 col-lg-6 text-center">
#      <form action="/search" class="navbar-form" method="GET" name="search" role="search" style="margin-top: 10px;">
#       <input name="beername" placeholder="Search" type="search"/>
#      </form>
#     </div>
#     <div class="col-xs-4 col-sm-3 col-md-2 col-lg-3 text-right">
#      <div class="norman">
#       <a class="btn btn-default" data-auth0="">
#        Login/Sign Up
#       </a>
#      </div>
#     </div>
#    </div>
#    <nav class="navbar navbar-default" role="navigation">
#     <!-- Brand and toggle get grouped for better mobile display -->
#     <div class="navbar-header">
#      <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#     </div>
#     <!-- Collect the nav links, forms, and other content for toggling -->
#     <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Beer
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/top">
#           Top 50
#          </a>
#         </li>
#         <li>
#          <a href="/beerstyles/">
#           Beer Styles
#          </a>
#         </li>
#         <li>
#          <a href="/tag/showall/">
#           Beer Tags
#          </a>
#         </li>
#         <li>
#          <a href="/beer-ratings/">
#           Recent Ratings
#          </a>
#         </li>
#         <li>
#          <a href="/breweries/">
#           Breweries
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/beerstyles/abbey-dubbel/71/">
#           Top By Style
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/BestInMyArea.asp?CountryID=213&amp;StateID=5">
#           Top By Region
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://community.ratebeer.com">
#         Forums
#        </a>
#       </li>
#       <li>
#        <a href="/places/browse/">
#         Places
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li>
#        <a href="/events">
#         Events
#        </a>
#       </li>
#       <li>
#        <a href="/users">
#         Community
#        </a>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         More
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/search.php">
#           <i class="glyphicon glyphicon-search">
#           </i>
#           Advanced Search
#          </a>
#         </li>
#         <li>
#          <a href="/AboutPremium_join.asp">
#           Buy Premium Membership
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/about.asp">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="/ratebeerbest/">
#           RateBeer Best
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- /.navbar-collapse -->
#    </nav>
#    <!--script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.7/jquery.min.js"></script-->
#    <script src="../javascript/jquery-ui-1.9.2.custom.min.js" type="text/javascript">
#    </script>
#    <script>
#     $( function() {
#     $( document ).tooltip({
#       position: {
#         my: "center bottom-20",
#         at: "center top",
#         using: function( position, feedback ) {
#           $( this ).css( position );
#           $( "<div>" )
#             .addClass( "arrow" )
#             .addClass( feedback.vertical )
#             .addClass( feedback.horizontal )
#             .appendTo( this );
#         }
#       }
#     });
#   } );
#    </script>
#    <style>
#     .table {
#     border-bottom:0px !important;
# }
# .table th, .table td {
#     border: 0px !important;
# }
#    </style>
#    <div class="container-fluid">
#     <div class="col-xl-offset-2 col-xl-8 col-lg-10 col-lg-offset-1 col-md-12">
#      <ul class="pull-left breadcrumb">
#       <li>
#        <a href="/">
#         Home
#        </a>
#       </li>
#       <li>
#        Ratings
#       </li>
#      </ul>
#      <div class="clearfix">
#      </div>
#      <h1>
#       Beer Ratings: Most Recent
#      </h1>
#      <p>
#       <small>
#       </small>
#      </p>
#      <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9 col-xl-9">
#       <br/>
#       <ul class="nav nav-tabs hidden-xs">
#        <li class="active" role="presentation">
#         <a href="/beer-ratings/">
#          Recent
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/5/">
#          New
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/4/">
#          Favs
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/1/">
#          Raves
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/2/">
#          Rants
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/3/">
#          Anomalous
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/AboutPremium.asp">
#          <span role="premie">
#           P
#          </span>
#          Friends
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/AboutPremium.asp">
#          Local
#         </a>
#        </li>
#       </ul>
#       <div class="dropdown hidden-sm hidden-md hidden-lg hidden-xl">
#        <button aria-expanded="true" aria-haspopup="true" class="btn btn-default dropdown-toggle form-control" data-toggle="dropdown" id="dropdownMenu1" type="button">
#         Show Ratings
#         <span class="caret">
#         </span>
#        </button>
#        <ul aria-labelledby="dropdownMenu1" class="dropdown-menu">
#         <li class="active" role="presentation">
#          <a href="/beer-ratings/">
#           Recent
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/1/">
#           Raves
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/2/">
#           Rants
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/3/">
#           Anomalous
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/4/">
#           High
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/5/">
#           New
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/AboutPremium.asp">
#           <span role="premie">
#            P
#           </span>
#           Friends
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/AboutPremium.asp">
#           Local
#          </a>
#         </li>
#        </ul>
#       </div>
#       <br/>
#       <table class="table" style="padding-right:20px;padding-top:100px;">
#        <tbody>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/wolf-traditional-esb/424754/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_13329.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_424754.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/wolf-traditional-esb/424754/91686/" style="font-size:20px; font-weight:bold;">
#            Wolf Traditional ESB
#           </a>
#           <span class="uas">
#            1.9
#           </span>
#           <div>
#            <a href="/brewers/wolf-brewing/13329/">
#             Wolf Brewing
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Nanaimo, British Columbia
#            </span>
#           </div>
#           <div style="color:#666;">
#            Pours with soft brown body and minimal foam, smells of brown sugar and those cheap halloween candies. Flavour is soft caramel and mountain due. Mouthfeel is cloying. This is a big miss for an ESB.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/91686/">
#             <span style="color:#8b8b8b;">
#              DeanF
#             </span>
#            </a>
#            <a href="/user/91686/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_DeanF.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/fair-state-high-plains-snifter/808447/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_20684.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_808447.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/fair-state-high-plains-snifter/808447/86363/" style="font-size:20px; font-weight:bold;">
#            Fair State High Plains Snifter
#           </a>
#           <span class="uas">
#            3.8
#           </span>
#           <div>
#            <a href="/brewers/fair-state-brewing-cooperative/20684/">
#             Fair State Brewing Cooperative
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Minneapolis, Minnesota
#            </span>
#           </div>
#           <div style="color:#666;">
#            On tap at the brewery. Pours a cloudy dark brown with a thin head that dissipates quickly and completely. Aroma has slightly dark grains with toffee, light dark berries and a bit of apple brandy underlying. Flavor has slightly dark grains and toffee with touches of apple brandy, blackberry and a hint of caramel backing.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/86363/">
#             <span style="color:#8b8b8b;">
#              deyholla
#             </span>
#            </a>
#            <a href="/user/86363/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_deyholla.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/new-belgium-voodoo-ranger-american-haze/797596/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_77.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_797596.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/new-belgium-voodoo-ranger-american-haze/797596/54824/" style="font-size:20px; font-weight:bold;">
#            New Belgium Voodoo Ranger American Haze
#           </a>
#           <span class="uas">
#            3.4
#           </span>
#           <div>
#            <a href="/brewers/new-belgium-brewing-company-lion-co-kirin-holdings/77/">
#             New Belgium Brewing Company (Lion Co. - Kirin Holdings)
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Fort Collins, Colorado
#            </span>
#           </div>
#           <div style="color:#666;">
#            12 ounce can from Woodman's Appleton, 2/6/20. Murky orange, large foamy white head, good retention. Aroma of dank, melon, pale malt and a bit of toast. Taste is resin, melon, dank, yuzu, pale malt. Medium bodied, low bitterness.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/54824/">
#             <span style="color:#8b8b8b;">
#              Drake
#             </span>
#            </a>
#            <a href="/user/54824/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_Drake.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/wolf-jinglepot-stout/385546/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_13329.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_385546.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/wolf-jinglepot-stout/385546/91686/" style="font-size:20px; font-weight:bold;">
#            Wolf Jinglepot Stout
#           </a>
#           <span class="uas">
#            3.4
#           </span>
#           <div>
#            <a href="/brewers/wolf-brewing/13329/">
#             Wolf Brewing
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Nanaimo, British Columbia
#            </span>
#           </div>
#           <div style="color:#666;">
#            Pours with good beige foam on a nice black body, smells of nice sweet dark milk chocolate. Flavour is good sharp cocoa with hints of sweet barley. Nice dryness on the mouth. This is decent and filling.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/91686/">
#             <span style="color:#8b8b8b;">
#              DeanF
#             </span>
#            </a>
#            <a href="/user/91686/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_DeanF.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/grayton-fish-whistle-ipa/446965/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_12957.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_446965.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/grayton-fish-whistle-ipa/446965/108216/" style="font-size:20px; font-weight:bold;">
#            Grayton Fish Whistle IPA
#           </a>
#           <span class="uas">
#            3.0
#           </span>
#           <div>
#            <a href="/brewers/grayton-beer-company/12957/">
#             Grayton Beer Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Santa Rosa Beach, Florida
#            </span>
#           </div>
#           <div style="color:#666;">
#            Pint at the Hurricane Oyster Bar. Pours a clear, brown color, with a small, beige head. The aroma is caramel, resin, toffee, rose, and wheat bread. Sweet and malty, with a mellow bitterness. Light to medium body, with a thin, sharp palate. Mediocre aromatics for an IPA, and pretty thin and weak. Fair.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/108216/">
#             <span style="color:#8b8b8b;">
#              GTAEgeek
#             </span>
#            </a>
#            <a href="/user/108216/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_GTAEgeek.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/finback-drop-a-line/808446/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_18825.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_808446.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/finback-drop-a-line/808446/86282/" style="font-size:20px; font-weight:bold;">
#            Finback Drop a Line
#           </a>
#           <span class="uas">
#            4.0
#           </span>
#           <div>
#            <a href="/brewers/finback-brewery/18825/">
#             Finback Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Queens, New York
#            </span>
#           </div>
#           <div style="color:#666;">
#            Can from Bottles in Providence, RI.  Very cloudy yellow-white, thin white medium-coarseness and moderate retention head.  Aroma is lovely big mango and dry mango, some dank onion, some passionfruit, some orange, touch of lime.  This smells lovely.  Medium weight, starchy semi-textured, slightly oily feel, medium-light carbonation, medium-coarseness, medium-light burn, silky.  Nice feel!  Flavor is sharp mango, bitter grapefruit, some dank herbs and onion, some orange, bit of tree sap, lingering green citrus and light rind bitterness.  Light and neutral barely balancing sweetness.  This is pretty great!
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/86282/">
#             <span style="color:#8b8b8b;">
#              PapaSkeetSkeet
#             </span>
#            </a>
#            <a href="/user/86282/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_PapaSkeetSkeet.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/cellarmaker-mild-smiles/791782/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_17792.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_791782.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/cellarmaker-mild-smiles/791782/70964/" style="font-size:20px; font-weight:bold;">
#            Cellarmaker Mild Smiles
#           </a>
#           <span class="uas">
#            4.1
#           </span>
#           <div>
#            <a href="/brewers/cellarmaker-brewing-company/17792/">
#             Cellarmaker Brewing Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             San Francisco, California
#            </span>
#           </div>
#           <div style="color:#666;">
#            Draft at Cellarmaker on nitro. Dark brown with a lasting tan head. Aroma is roast, coffee, cocoa, earth. Flavor is dry and super balanced. Roasty, earthy, very nice. Medium body with a very smooth feel. Hell of a mild.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/70964/">
#             <span style="color:#8b8b8b;">
#              nickd717
#             </span>
#            </a>
#            <a href="/user/70964/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_nickd717.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/le-saint-bock-malediction/84944/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_8288.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_84944.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/le-saint-bock-malediction/84944/121285/" style="font-size:20px; font-weight:bold;">
#            Le Saint-Bock Malédiction
#           </a>
#           <span class="uas">
#            2.8
#           </span>
#           <div>
#            <a href="/brewers/le-saint-bock-brasserie-artisanale/8288/">
#             Le Saint-Bock - Brasserie Artisanale
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             

#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/121285/">
#             <span style="color:#8b8b8b;">
#              rejtable
#             </span>
#            </a>
#            <a href="/user/121285/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_rejtable.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/urban-artifact-astrolabe/798356/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_22624.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_798356.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/urban-artifact-astrolabe/798356/87939/" style="font-size:20px; font-weight:bold;">
#            Urban Artifact Astrolabe
#           </a>
#           <span class="uas">
#            3.5
#           </span>
#           <div>
#            <a href="/brewers/urban-artifact-brewing/22624/">
#             Urban Artifact Brewing
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Cincinnati, Ohio
#            </span>
#           </div>
#           <div style="color:#666;">
#            12 oz can from Tavour, 2/6/20.  Pours purple, smallish head, no lace.  Smells like Manischewitz.  Tastes along the same lines.  Bit of vanilla, slightly.  This works better as a beer than it does as a Passover wine, but it's still not amazing.  Concord grapes might be a fruit that's just better for eating than drinking.  I think it's well made, no complaints there.
# 7/3/7/3/15
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/87939/">
#             <span style="color:#8b8b8b;">
#              ben4321
#             </span>
#            </a>
#            <a href="/user/87939/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_ben4321.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/hardywood-frosty-gbs/808441/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_13558.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_808441.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/hardywood-frosty-gbs/808441/645812/" style="font-size:20px; font-weight:bold;">
#            Hardywood Frosty GBS
#           </a>
#           <span class="uas">
#            3.7
#           </span>
#           <div>
#            <a href="/brewers/hardywood-park-craft-brewery/13558/">
#             Hardywood Park Craft Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Richmond, Virginia
#            </span>
#           </div>
#           <div style="color:#666;">
#            Medium gold pour. Thin foam. Sweet nose of spices and hints of cocoa. Lovely lovely sweet  taste of coconut with a nice coconut pala
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/645812/">
#             <span style="color:#8b8b8b;">
#              Susie33
#             </span>
#            </a>
#            <a href="/user/645812/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_Susie33.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/quidi-vidi-bog-and-barrens/678697/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_1257.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_678697.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/quidi-vidi-bog-and-barrens/678697/121285/" style="font-size:20px; font-weight:bold;">
#            Quidi Vidi Bog and Barrens
#           </a>
#           <span class="uas">
#            3.5
#           </span>
#           <div>
#            <a href="/brewers/quidi-vidi-brewing-company/1257/">
#             Quidi Vidi Brewing Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             St. John's, Newfoundland
#            </span>
#           </div>
#           <div style="color:#666;">
#            Can from friend. Pours brown coffee some head and lacing. Notes are roasted grain, some espresso, light tart berries. Taste medium bitter medium sweet. Medium creamy body lively carbonation.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/121285/">
#             <span style="color:#8b8b8b;">
#              rejtable
#             </span>
#            </a>
#            <a href="/user/121285/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_rejtable.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div>
#        <div style="width: 200px; margin:0 auto;">
#         <div style="float: right;">
#          <a href="/beer-ratings/0/2/">
#           <img alt="next" border="0" src="/images/buttons/arrow-right.png"/>
#           Next
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-xl-2 col-lg-3 col-md-3 col-sm-12 col-xs-12">
#       <div style="width:100%;">
#        <div id="tagside">
#         <a href="/beer/top-50/">
#          Top Rated Beer
#         </a>
#        </div>
#        <div style="padding: 10px;">
#         <span class="shortlist">
#          The overall Top 50 active beers as determined by our
#          <a href="/users">
#           worldwide community of beer raters
#          </a>
#         </span>
#         <br/>
#         <br/>
#        </div>
#        <script language="JavaScript">
#         <!-- Hide the script from old browsers --
# function goto(form) { var index=form.select.selectedIndex
# if (form.select.options[index].value != "0") {
# location=form.select.options[index].value;}}//-->
#        </script>
#        <form name="jump1">
#         <select class="form-control" id="menu" name="menu" onchange="location=document.getElementById('menu').value;" style="background-color: #E9F3Ff; color: #333; font-size: 13px; margin-bottom:6px; padding: 4px; border: 1px solid #B9DAF0;" value="GO">
#          <option value="0">
#           Best by Style
#          </option>
#          <option value="/beerstyles/altbier-sticke-alt/2/">
#           Altbier / Sticke Alt
#          </option>
#          <option value="/beerstyles/amber-lager-czech-polotmavy/115/">
#           Amber Lager - Czech / Polotmavý
#          </option>
#          <option value="/beerstyles/amber-lager-intl-vienna/36/">
#           Amber Lager - Intl / Vienna
#          </option>
#          <option value="/beerstyles/apple-cider/10/">
#           Apple Cider
#          </option>
#          <option value="/beerstyles/apple-cider-flavored/171/">
#           Apple Cider - Flavored
#          </option>
#          <option value="/beerstyles/apple-cider-hopped/172/">
#           Apple Cider - Hopped
#          </option>
#          <option value="/beerstyles/apple-cider-ice-fire-fortified/112/">
#           Apple Cider-Ice/Fire/Fortified
#          </option>
#          <option value="/beerstyles/barleywine-wheatwine-ryewine/11/">
#           BarleyWine / WheatWine / RyeWine
#          </option>
#          <option value="/beerstyles/belgian-ale-dark-amber/128/">
#           Belgian Ale - Dark / Amber
# ...
#          </option>
#          <option value="/beer/country/uzbekistan/214/">
#           Uzbekistan
#          </option>
#          <option value="/beer/country/vanuatu/215/">
#           Vanuatu
#          </option>
#          <option value="/beer/country/vatican-city/216/">
#           Vatican City
#          </option>
#          <option value="/beer/country/venezuela/217/">
#           Venezuela
#          </option>
#          <option value="/beer/country/vietnam/218/">
#           Vietnam
#          </option>
#          <option value="/beer/country/wales/239/">
#           Wales
#          </option>
#          <option value="/beer/country/western-sahara/266/">
#           Western Sahara
#          </option>
#          <option value="/beer/country/yemen/248/">
#           Yemen
#          </option>
#          <option value="/beer/country/zambia/222/">
#           Zambia
#          </option>
#          <option value="/beer/country/zimbabwe/223/">
#           Zimbabwe
#          </option>
#         </select>
#        </form>
#        <div style="">
#         <!--<br><a href="/beer/top-50/"><b>Ratebeer Top 50</b></a> overall-->
#         <br/>
#         <a href="http://www.ratebeerbest.com">
#          <img src="/images/logos/rbbest16.png" width="230"/>
#         </a>
#         <br/>
#         <!--a style="text-align:center;" href="http://www.ratebeerbest.com/"><b>RB Best Awards List</b></a-->
#        </div>
#        <style>
#         .shortlist{font-size:13px;text-align:left;}
#        </style>
#        <link href="/css/tags.css" rel="stylesheet" type="text/css"/>
#       </div>
#       <br/>
#       <br/>
#       <div id="tagside">
#        <a href="/tag/showall/">
#         Beer Tags
#        </a>
#       </div>
#       <div style="text-align: left;">
#        <span class="tags">
#         <a href="/tag/collaboration/" style="font-size: 12px;">
#          collaboration
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/citra/" style="font-size: 12px;">
#          citra
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/vanilla/" style="font-size: 12px;">
#          vanilla
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/mosaic/" style="font-size: 12px;">
#          mosaic
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/lactose/" style="font-size: 12px;">
#          lactose
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/oats/" style="font-size: 12px;">
#          oats
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/simcoe/" style="font-size: 12px;">
#          simcoe
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/barrel-aged/" style="font-size: 12px;">
#          barrel aged
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/galaxy/" style="font-size: 12px;">
#          galaxy
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/coffee/" style="font-size: 12px;">
#          coffee
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cascade/" style="font-size: 12px;">
#          cascade
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/amarillo/" style="font-size: 12px;">
#          amarillo
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/dry-hopped/" style="font-size: 12px;">
#          dry hopped
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/canned/" style="font-size: 12px;">
#          canned
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/nelson-sauvin/" style="font-size: 12px;">
#          nelson sauvin
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cacao-nibs/" style="font-size: 12px;">
#          cacao nibs
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/gluten-free/" style="font-size: 12px;">
#          gluten free
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/columbus/" style="font-size: 12px;">
#          columbus
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/bourbon-ba/" style="font-size: 12px;">
#          bourbon ba
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/sabro/" style="font-size: 12px;">
#          sabro
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/single-hop/" style="font-size: 12px;">
#          single hop
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/triple-ipa/" style="font-size: 12px;">
#          triple ipa
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/sugar/" style="font-size: 12px;">
#          sugar
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/chinook/" style="font-size: 12px;">
#          chinook
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/wheat/" style="font-size: 12px;">
#          wheat
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/white-stout/" style="font-size: 12px;">
#          white stout
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/whiskey-ba/" style="font-size: 12px;">
#          whiskey ba
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cinnamon/" style="font-size: 12px;">
#          cinnamon
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/chocolate/" style="font-size: 12px;">
#          chocolate
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/coconut/" style="font-size: 12px;">
#          coconut
#         </a>
#        </span>
#        <a class="btn btn-sm btn-warning" href="/tag/showall/">
#         show all
#        </a>
#       </div>
#       <br/>
#       <br/>
#       <div 1.75;"="" line-height:="" style="style=">
#        <div id="tagside">
#         More Lists
#        </div>
#        <a href="/top">
#         Customizable Top 50
#        </a>
#        <br/>
#        <a href="/beer/top-50-beer-gods/">
#         Beer Gods' Top 50 Beers
#        </a>
#        <br/>
#        <a href="/Ratings/TopAccessible.asp">
#         Top Widely Distributed Beers
#        </a>
#        <br/>
#        <a href="/Ratings/BigNewBeers.asp">
#         Top Big New Beers
#        </a>
#        <br/>
#        <a href="/Ratings/TopSeasonals.asp">
#         Top Seasonal Beers
#        </a>
#        <br/>
#        <a href="/Ratings/Top90Days.asp">
#         The Last 90 Days
#        </a>
#        <br/>
#        <span class="premie">
#         P
#        </span>
#        <a href="/Ratings/Top50Retired.asp">
#         Top 50 Retired Beers
#        </a>
#        <br/>
#        <a href="/Ratings/MakeOrBreak.asp">
#         Make It Or Break It
#        </a>
#        <br/>
#        <a href="/Ratings/newgood.asp">
#         Top Newly Listed Beers
#        </a>
#        <br/>
#        <a href="/Ratings/topstrong.asp">
#         Top Strong Beers
#        </a>
#        <br/>
#        <a href="/ratings/most-difficult-countries/">
#         Most Difficult Countries to Drink
#        </a>
#        <br/>
#        <br/>
#        <a href="/Ratings/TopSakes.asp">
#         Top Sake
#        </a>
#        <br/>
#        <a href="/Ratings/TopMeads.asp">
#         Top Mead
#        </a>
#        <br/>
#        <a href="/Ratings/TheWorstBeers.asp">
#         The Worst Beers In The World
#        </a>
#        <br/>
#        <br/>
#        <div id="tagside">
#         Even More Lists
#        </div>
#        <a href="/Ratings/MostActiveBrewers.asp">
#         The Most Active Brewers
#        </a>
#        <br/>
#        <a href="/Ratings/TopAlcohol.asp">
#         The Strongest Beers In The World
#        </a>
#        <br/>
#        <a href="/Ratings/TopUltralights.asp">
#         Top Session Strength
#        </a>
#        <br/>
#        <a href="/Ratings/TopWeekly.asp">
#         The Top Weekly
#        </a>
#        <br/>
#        <a href="/Ratings/TopIBU.asp">
#         The Top IBU
#        </a>
#        <br/>
#        <a href="/Ratings/TopOfTheMonth.asp">
#         Top Beers of the Month
#        </a>
#        <br/>
#        <span class="premie">
#         P
#        </span>
#        <a href="/Ratings/TopMostWanted.asp">
#         The Most Wanted Beers
#        </a>
#        <br/>
#        <a href="/NewBeers.asp">
#         Newest Beers
#        </a>
#        <br/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <br/>
#   <br/>
#   <!--=== Footer ===-->
#   <br/>
#   <br/>
#   <div class="footer">
#    <div class="container" style="border-top: 1px solid #e0e0e0">
#     <br/>
#     <br/>
#     <div class="clearfix">
#      <div class="col-md-4 md-margin-bottom-40">
#       <!-- About -->
#       <img alt="ratebeer logo" src="/images/logos/rbfooter2.png" width="131"/>
#       <br/>
#       <br/>
#       <h4>
#        Contact us
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/about">
#         About Us
#        </a>
#        <br/>
#        <a href="/faq">
#         Frequently Asked Questions
#        </a>
#        <br/>
#        <a href="/feedback">
#         Feedback
#        </a>
#        <br/>
#        <br/>
#        <a href="https://play.google.com/store/apps/details?id=com.ratebeer&amp;utm_source=RateBeer&amp;utm_medium=footer&amp;utm_campaign=public_launch">
#         <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png" style="width:168px;"/>
#        </a>
#        <br/>
#        <a href="https://itunes.apple.com/us/app/keynote/id1221018606?mt=8&amp;utm_source=RateBeer&amp;utm_medium=footer&amp;utm_campaign=public_launch">
#         <img alt="Get it on the App Store" src="/images/App_Store_Badge_US-UK_135x40.svg" style="padding: 10px; width: 170px;"/>
#        </a>
#       </p>
#       <!-- End About -->
#       <br/>
#       <!-- End Monthly Newsletter -->
#      </div>
#      <!--/col-md-4-->
#      <div class="col-md-4 md-margin-bottom-40">
#       <h4>
#        Add To RateBeer
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/add-beer">
#         Add A Beer
#        </a>
#        <br/>
#        <a href="/add-brewer">
#         Add A Brewer
#        </a>
#        <br/>
#        <a href="/add-place">
#         Add A Place
#        </a>
#        <br/>
#        <a href="/add-event">
#         Add An Event
#        </a>
#       </p>
#       <br/>
#       <h4>
#        Manage Your Account
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/AboutPremium_Join.asp">
#         Add Premium
#        </a>
#        <br/>
#        <a href="/EditUser.asp">
#         Edit Profile
#        </a>
#        <br/>
#        <a href="/Messages.asp">
#         Messages
#        </a>
#        <br/>
#        <a href="/signout.asp">
#         Sign out
#        </a>
#        <br/>
#       </p>
#      </div>
#      <!--/col-md-4-->
#      <div class="col-md-4">
#       <!-- Monthly Newsletter -->
#       <h4>
#        RateBeer Newsletter
#       </h4>
#       <p>
#        Subscribe to our newsletter, RateBeer Weekly, a must for understanding new people, places and beers in worldwide craft culture.
#       </p>
#       <div id="mc_embed_signup">
#        <form action="//ratebeer.us2.list-manage.com/subscribe/post?u=927a170c4a7bc5ac2c11d7a5f&amp;id=33216a9626" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
#         <div id="mc_embed_signup_scroll">
#          <!--label for="mce-EMAIL">Subscribe to our mailing list</label-->
#          <input class="form-control" id="mce-EMAIL" name="EMAIL" placeholder="email address" required="" type="email" value=""/>
#          <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
#          <div style="position: absolute; left: -5000px;">
#           <input name="b_927a170c4a7bc5ac2c11d7a5f_33216a9626" tabindex="-1" type="text" value=""/>
#          </div>
#          <div class="clear">
#           <input class="btn btn-primary" id="mc-embedded-subscribe" name="subscribe" style="margin-top: 5px;" type="submit" value="Subscribe"/>
#          </div>
#         </div>
#        </form>
#       </div>
#       <!--End mc_embed_signup-->
#       <!-- End Social Links -->
#       <br/>
#       <!-- Social Links -->
#       <h4>
#        Stay Connected
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="https://www.facebook.com/pages/RateBeer/153277718016808">
#         <i class="fa fa-facebook-square fa-3x social-fb" id="social">
#         </i>
#        </a>
#        <a href="https://twitter.com/ratebeer">
#         <i class="fa fa-twitter-square fa-3x social-tw" id="social">
#         </i>
#        </a>
#        <a href="https://plus.google.com/112964660796936121915/posts">
#         <i class="fa fa-google-plus-square fa-3x social-gp" id="social">
#         </i>
#        </a>
#        <!--a href="mailto:@ratebeer.com"><i id="social" class="fa fa-envelope-square fa-3x social-em"></i></a-->
#       </p>
#      </div>
#      <!--/col-md-4-->
#     </div>
#    </div>
#   </div>
#   <!--/footer-->
#   <!--=== End Footer ===-->
#   <br/>
#   <br/>
#   <!--=== Copyright ===-->
#   <div class="copyright">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-6">
#       <p>
#        2000-
#           2020 © RateBeer, LLC. All Rights Reserved.
#        <a href="/privacy_policy.asp">
#         Privacy Policy
#        </a>
#        |
#        <a href="/useragreement.asp">
#         Terms of Service
#        </a>
#       </p>
#      </div>
#      <div class="col-md-6">
#       <a href="/">
#        <!--img class="pull-right" id="logo-footer" src="assets/img/logo2-default.png" alt=""-->
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--/copyright-->
#   <!--=== End Copyright ===-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	var isLoggedIn =
#
# 	ga('create', 'UA-1881232-1', 'auto');
#
# 	if (isLoggedIn > 0) {
# 		ga('send', {
# 			hitType: 'pageview',
# 			'dimension2': 'LoggedInUser'
# 		});
# 	} else {
# 			ga('send', 'pageview')
# 	}
#   </script>
#   <script src="/js/form-validation.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var getUrlParameter = function getUrlParameter(sParam) {
#     var sPageURL = decodeURIComponent(window.location.search.substring(1)),
#         sURLVariables = sPageURL.split('&'),
#         sParameterName,
#         i;
#
#     for (i = 0; i < sURLVariables.length; i++) {
#       sParameterName = sURLVariables[i].split('=');
#
#       if (sParameterName[0] === sParam) {
#         return sParameterName[1] === undefined ? true : sParameterName[1];
#       }
#     }
#   };
#   </script>
#   <script src="https://cdn.auth0.com/js/lock/11.3.1/lock.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.auth0.com/js/auth0/9.3.3/auth0.min.js">
#   </script>
#   <script src="/js/auth-zero-btn.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .auth0-lock.auth0-lock .auth0-lock-submit {
#     background: #0098CD!important;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-input-wrap,
#   .auth0-lock.auth0-lock .auth0-lock-social-button,
#   .auth0-lock.auth0-lock .auth0-lock-cred-pane {
#     border-radius: 12px;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-input-wrap .auth0-lock-input {
#     border-radius: 0 12px 12px 0;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-header {
#     border-radius: 12px 12px 0 0;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-submit {
#     border-radius: 0 0 12px 12px;
#   }
#   #auth0-container {
#     width: 320px;
#     max-height: 498px;
#     margin: 40px auto;
#     padding: 10px;
#     box-sizing: border-box;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-header-logo {
#     height: 92px;
#   }
#   .auth0-lock-name {
#     display:none;
#   }
#   </style>
#   <script type="text/javascript">
#    window.userIsLoggedIn=false;
#   </script>
#   <!-- defer redirects -->
#   <script type="text/javascript">
#    $('[defer-redirect]').on('click', function (event) {
#     if (!window.userIsLoggedIn) {
#       event.preventDefault();
# 	  Auth0.signin();
#     }
#   });
#   </script>
#  </body>
# </html>

# %% [markdown]
# ### Let's inspect the page - some snips

# %% [markdown]
# ![inspect1](Images/inspect1.PNG)

# %% [markdown]
# ![inspect2](Images/inspectcontinued.PNG)

# %% [markdown]
# ## Get list of urls for tabs
# #### there are 6 tabs that allow access without registration: Recent, New, Faves, Raves, Rants, Anomalous
# #### while the tab for My Local doesn't allow access, simply typing a '7' after the url gives full access
# #### the max pages are accurate as of 2/6/20

# %% [markdown]
# ### Recent Tab

# %%
# https://www.ratebeer.com/beer-ratings/0/1/       #### 1st page 
# https://www.ratebeer.com/beer-ratings/0/2/       #### 2nd page 
# https://www.ratebeer.com/beer-ratings/0/100/     #### last page

# %% [markdown]
# ### New

# %%
# https://www.ratebeer.com/beer-ratings/5/1/      #### 1st page 
# https://www.ratebeer.com/beer-ratings/5/2/      #### 2nd page
# https://www.ratebeer.com/beer-ratings/5/85/     #### last

# %% [markdown]
# ### Faves

# %%
# https://www.ratebeer.com/beer-ratings/4/1/       #### 1st page 
# https://www.ratebeer.com/beer-ratings/4/2/       #### 2nd page 
# https://www.ratebeer.com/beer-ratings/4/100/     #### last page

# %% [markdown]
# ### Raves

# %%
# https://www.ratebeer.com/beer-ratings/1/1/        #### 1st page
# https://www.ratebeer.com/beer-ratings/1/2/        #### 2nd page
# https://www.ratebeer.com/beer-ratings/1/100/      #### max page

# %% [markdown]
# ### Rants

# %%
# https://www.ratebeer.com/beer-ratings/2/1/       #### 1st page
# https://www.ratebeer.com/beer-ratings/2/2/       #### 2nd page
# https://www.ratebeer.com/beer-ratings/2/100/     #### max page

# %% [markdown]
# ### Anomalous

# %%
# https://www.ratebeer.com/beer-ratings/3/1/        #### 1st page
# https://www.ratebeer.com/beer-ratings/3/2/        #### 2nd page
# https://www.ratebeer.com/beer-ratings/3/100/     #### max page

# %%
# https://www.ratebeer.com/beer-ratings/6/       #### requires log in

# %% [markdown]
# ### My Local

# %%
# https://www.ratebeer.com/beer-ratings/7/1/       #### 1st page
# https://www.ratebeer.com/beer-ratings/7/2/      #### 2nd page
# https://www.ratebeer.com/beer-ratings/7/100/    #### max page

# %% [markdown]
# ## Now we need to consider the urls in the scraper so we are not using the wrong urls

# %% [markdown]
# ### Recent Urls

# %%
recent_url = 'http://www.ratebeer.com/beer-ratings/0/' # 'most recent' review page
count = 1
while count < 5:                    #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# http://www.ratebeer.com/beer-ratings/0/2/
# http://www.ratebeer.com/beer-ratings/0/3/
# http://www.ratebeer.com/beer-ratings/0/4/

# %%
# fixed

# %% [markdown]
# ### Beer Name Scrape from Recent Tab

# %%
# # set 'count < 100' to return all pages 
# beers = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/' # 'most recent' review page
# count = 1
# while count < 5:                    #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages (returns 1st 4)
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url) #comment out if you dont want to see all the lines printed

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     name_soup = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
      
#     for beer_name in name_soup:
#         print(beer_name.text)  
#         beers.append(beer_name.text)

# %%
# print(beers) #now we have a list of all the names of the beer from recents tab

# %%
# ratings = soup.findAll('span', attrs={"class": "uas"})
# ratings
# for rating in ratings:
#     print(rating.text)

# %%
# from 'recent'
# beer_ratings = []
# url = 'http://www.ratebeer.com/beer-ratings/'
# count = 0
# while count < 2:
#     new_url = (f'{url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     rating_soup = soup.findAll('span', attrs={'class':'uas'})
# #       
#     for beer_rating in rating_soup:
#         print(beer_rating.text)
#         beer_ratings.append(beer_rating.text)

# %%
# print(beer_ratings)

# %%
# we need to get ride of that '\xa0'
# beer_ratings.remove('\xa0')

# %%
# print(beer_ratings) #there are more than 1 so we got rid of the first value only

# %% [markdown]
# #### fixed

# %%
# lets try changing loop to this: 
# for beer_rating in rating_soup:
#     if beer_rating.text == '\xa0':
#         pass
#     else:
#         print(beer_rating.text)
#         beer_ratings.append(beer_rating.text)

# %% [markdown]
# ### Rating Scrape from Recent tab

# %% [markdown]
# #### Navigate to Pretty Tree:
# [Pretty Tree](#Pretty_Tree)

# %%
# # from 'most recent' reviews page
# beer_ratings = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     rating_soup = soup.findAll('span', attrs={'class':'uas'})
    
#     for beer_rating in rating_soup:
#         if beer_rating.text == '\xa0':
#             pass
#         else:
#             print(beer_rating.text)
#             beer_ratings.append(beer_rating.text)

# %%
# print(beer_ratings)

# %%
# now lets put it together
# using naive method 
# to convert lists to dictionary 
# resulting_dict = {} 
# for key in test_keys: 
#     for value in test_values: 
#         res[key] = value 
#         test_values.remove(value) 
#         break

# %%
# Using naive method
# name_rating = {}
# for key in beers:
#     for value in beer_ratings:
#         name_rating[key] = value
#         beer_ratings.remove(value)
#         break

# %%
# next time using list comprehension since it looks cooler
# using dictionary comprehension 
# to convert lists to dictionary 
# res = {test_keys[i]: test_values[i] for i in range(len(test_keys))}

# %%
print(name_rating)

# %% [markdown]
# <div class="alert alert-info">
# <strong>Note: The items are accurate per the links! If you want to get the max pages, just change BOTH scrape loops from 'count < 5' to 'count < 100'
# </div>

# %% [markdown]
# ### Simply change the soup recipie for the loop and get the review text, location ... and update list

# %% [markdown]
# ### Get text reviews scrape from Recent tab

# %%
#  add a teaspoon of text 
# breweries_rating_texts = soup.findAll('div', {'style': 'color:#666;'})

# %%
# # from 'most recent' reviews page
# reviews = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     review_soup = soup.findAll('div', {'style':'color:#666;'})
    
#     for review in review_soup:
#             print(review.text)
#             reviews.append(review.text)

# %%
# print(reviews)

# %% [markdown]
# ### Get location scrape from Recent

# %%
# soup.findAll('span')
# locations = soup.findAll('span', {'class': 'small'})

# %%
# # from 'most recent' reviews page
# locations = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     location_soup = soup.findAll('span', {'class': 'small'})
    
#     for location in location_soup:
#             print(location.text.rstrip())
#             locations.append(location.text.rstrip())

# %%
# print(locations)

# %% [markdown]
# ### Get user info from Recent

# %% [markdown]
# #### Navigate to Pretty Tree:
# [Pretty Tree](#Pretty_Tree)

# %%
# user_soup = something like this where loubar is the user_name and 334082 is the user_id

# <a class="small" href="/user/334082/">
#             <span style="color:#8b8b8b;">            <<<<<<< lets try this 
#              loubar
#             </span>
#            </a>
#            <a href="/user/334082/">

# %%
# # from 'most recent' reviews page
# users = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
#     for user in user_soup:
#             print(user.text)
#             users.append(user.text)

# %% [markdown]
# ### retuning the location of the brewery AND then the user who wrote review because they are the same color

# %%
# try skipping every other one or fix the query 

# Slice notation a[start_index:end_index:step]

# return a[::2]
# where start_index defaults to 0 and end_index defaults to the len(a).

# %%
# # from 'most recent' reviews page
# users = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
#     for user in user_soup:
#             print(user.text[::2])
# #             users.append(user.text)

# %%
# not quite there yet

# %%
# # from 'most recent' reviews page
# users = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
#     for user in user_soup[::2]:
#             print(user.text)
#             users.append(user.text)

# %%
# Getting warmer

# %% [markdown]
# ### keep trying
# arr = list(range(10)) # Range from 0-9
#
# ### List comprehension: Range with conditional
# print [arr[index] for index in range(len(arr)) if index % 2 == 0]
#
# ### List comprehension: Range with step
# print [arr[index] for index in range(0, len(arr), 2)]
#
# ### List comprehension: Enumerate with conditional
# print [item for index, item in enumerate(arr) if index % 2 == 0]
#
# ### List filter: Index in range
# print filter(lambda index: index % 2 == 0, range(len(arr)))
#
# ### Extended slice
# print arr[::2]

# %%
# # from 'most recent' reviews page
# users = []
# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
# count = 1
# while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
#     for user in user_soup[1::2]:
#             print(user.text)
# #             users.append(user.text)

# %%
# fixed

# %% [markdown]
# ### Recap: We now have the ability to scrape user names, review, ratings, beer names and location of brewery
# #### It might not have been pretty, but it works

# %% [markdown]
# ### Once funtion is defined, we can easily replace the url for the other tabs, such as favs, raves, new, ...

# %% [markdown]
# ## Let's put it all together now

# %%
# Combined scrape from 'most recent' reviews page

# beers = []
# ratings = []
# locations = []
# reviews = []
# users = []

# recent_url = 'http://www.ratebeer.com/beer-ratings/0/'

# count = 1
# while count < 2:                  #=|>>>>>>>>>>  change the 'count < x' to increase scrape up to 100 pages
#     new_url = (f'{recent_url}{count}/')
#     count +=1
#     print(new_url)

#     page = requests.get(new_url, verify=True)
#     page.status_code

# #   make a nice soup 
#     soup = BeautifulSoup(page.text, 'html.parser')
    
#     print("Beer Names: ")
                  
# #   beer names scrape        
#     name_soup = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
      
#     for beer_name in name_soup:
#         print(beer_name.text)  
#         beers.append(beer_name.text)
        
#     print("Beer Ratings: ")
        
# #   ratings scrape
#     rating_soup = soup.findAll('span', attrs={'class':'uas'})
    
#     for beer_rating in rating_soup:
#         if beer_rating.text == '\xa0':
#             pass
#         else:
#             print(beer_rating.text)
#             ratings.append(beer_rating.text)
    
#     print("Brewery Locations: ")
# #   location scrape
#     location_soup = soup.findAll('span', {'class': 'small'})
    
#     for location in location_soup:
#             print(location.text.rstrip())
#             locations.append(location.text.rstrip())
            
#     print("User Reviews: ")
    
# #   review scrape
#     review_soup = soup.findAll('div', {'style':'color:#666;'})
    
#     for review in review_soup:
#             print(review.text)
#             reviews.append(review.text)
            
#     print("User Names: ")
    
# #   user scrape
#     user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
#     for user in user_soup[1::2]:
#             print(user.text)
#             users.append(user.text)

# %%
# current lists (from the recent tab)
# beers = []
# ratings = []
# locations = []
# reviews = []
# users = []

# %%
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
new_beer_url = 'http://www.ratebeer.com/beer-ratings/5/' #85 max
favs_url = 'http://www.ratebeer.com/beer-ratings/4/'
raves_url = 'http://www.ratebeer.com/beer-ratings/1/'
rants_url = 'http://www.ratebeer.com/beer-ratings/2/'
anomalous_url = 'http://www.ratebeer.com/beer-ratings/3/'
local_url = 'http://www.ratebeer.com/beer-ratings/7/'

urls = [recent_url, favs_url, raves_url, rants_url, local_url]

# %%
for u in urls:
    print(u)
# Out:
# http://www.ratebeer.com/beer-ratings/0/
# http://www.ratebeer.com/beer-ratings/4/
# http://www.ratebeer.com/beer-ratings/1/
# http://www.ratebeer.com/beer-ratings/2/
# http://www.ratebeer.com/beer-ratings/7/

# %% [markdown]
# ### Adding a url loop

# %%
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
new_beer_url = 'http://www.ratebeer.com/beer-ratings/5/' #85 max
favs_url = 'http://www.ratebeer.com/beer-ratings/4/'
raves_url = 'http://www.ratebeer.com/beer-ratings/1/'
rants_url = 'http://www.ratebeer.com/beer-ratings/2/'
anomalous_url = 'http://www.ratebeer.com/beer-ratings/3/'
local_url = 'http://www.ratebeer.com/beer-ratings/7/'

urls = [recent_url, favs_url, raves_url, rants_url, local_url]


beers = []
ratings = []
locations = []
reviews = []
users = []

count = 1
while count < 100:
    for u in urls:
        
        new_url = (f'{u}{count}/')
        count +=1
        print(new_url)

        page = requests.get(new_url, verify=True)
        page.status_code

    #   make a nice soup 
        soup = BeautifulSoup(page.text, 'html.parser')

        print("Beer Names: ")

    #   beer names scrape        
        name_soup = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})

        for beer_name in name_soup:
            print(beer_name.text)  
            beers.append(beer_name.text)

        print("Beer Ratings: ")

    #   ratings scrape
        rating_soup = soup.findAll('span', attrs={'class':'uas'})

        for beer_rating in rating_soup:
            if beer_rating.text == '\xa0':
                pass
            else:
                print(beer_rating.text)
                ratings.append(beer_rating.text)

        print("Brewery Locations: ")
    #   location scrape
        location_soup = soup.findAll('span', {'class': 'small'})

        for location in location_soup: 
                print(location.text.rstrip())
                locations.append(location.text.rstrip())

        print("User Reviews: ")

    #   review scrape
        review_soup = soup.findAll('div', {'style':'color:#666;'})

        for review in review_soup:
                print(review.text)
                reviews.append(review.text)

        print("User Names: ")

    #   user scrape
        user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})

        for user in user_soup[1::2]:
                print(user.text)
                users.append(user.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# Beer Names:
# Sierra Nevada Fantastic Haze
# Burley Oak Jelly Not Jam - Cherry, Raspberry, and Strawberry
# Blue Moon Raven's Moon Asian Pear Cider
# Wolf Traditional ESB
# Fair State High Plains Snifter
# New Belgium Voodoo Ranger American Haze
# Wolf Jinglepot Stout
# Grayton Fish Whistle IPA
# Finback Drop a Line
# Cellarmaker Mild Smiles
# Le Saint-Bock Malédiction
# Wicked Weed Oblivion Sour Red
# Good City Varietal Series: Waimea
# Le Saint-Bock Malédiction Donut
# Sawdust City Maple Butter Tart Ale
# Beer Ratings:
# 3.1
# 3.8
# 2.7
# 1.9
# 3.8
# 3.4
# 3.4
# 3.0
# 4.0
# 4.1
# 2.8
# 3.7
# 3.5
# 2.6
# 3.2
# Brewery Locations:
# Chico, California
# Berlin, Maryland
# Courtenay, British Columbia
# Nanaimo, British Columbia
# Minneapolis, Minnesota
# Fort Collins, Colorado
# Nanaimo, British Columbia
# Santa Rosa Beach, Florida
# Queens, New York
# San Francisco, California
# Montréal, Quebec
# Asheville, North Carolina
# Milwaukee, Wisconsin
# Montréal, Quebec
# Gravenhurst, Ontario
# User Reviews:
# Large off white head with good retention and a nice lace. Lightly hazy blond. Nose is mango and a little citrus. Body is medium, ain’t juicy, prickly carbo. Just some lightly sweet pale malts and lightly fruity hops. Dry, lightly bitter finish. Seems SN is trying a bit too hard. 12oz can from statelineliquors.
# Can from the brewery. Pours hazy orange/red with a thin, fizzy head. Tastes like tart citrus, berry, cookie malt, and sour yeast. Light body and low carbonation. Smells like berry, yeast, sour dough, and cookie malt.
# Overall: excellent balanced sweet barley malts, very nice mouthfeel, smooth drinking.
# Poured from a 16 oz can.
# Aroma is malt forward with lots of grain, cracker, biscuit and toasted bread notes. Light herbal, spicy hop notes with hints of floral character.
# Pours a slightly hazy, brilliant gold color with a large, thick, frothy, white head that recedes slowly to a small film that lingers a bit on the edges. Moderately high lacing and no legs.
# Flavor is somewhat sweet with moderately strong grain notes of bread, cracker, and biscuit. Moderately strong bitterness with medium light hop notes of woody, herbal and spicy notes with faint floral character and a hint of fruit esters.
# Mouthfeel is light bodied with medium carbonation. Low astringency and low alcohol warmth.
# Overall, a pretty enjoyable lager. Nice malt notes with assertive bitterness and hop notes. Hop notes and bitterness are not too strong though and malt is still center stage.
# Poured from 12 oz. bottle.
#
# Clear, bright yellow with a 2-finger near white head and good lacing.
#
# Aroma of white grapes, a strange citrus-like aroma I don’t recognize and exotic tropical fruit.
#
# Taste follows the nose closely.
#
# Medium body and medium carbonation.
#
# This has a distinctive hopping that is nothing like anything I’ve experienced before. I welcome the addition to the brewmaster’s pallet, but I find this beer is a little too grapey for my taste.
# 500ml bottle at home via VA.  Hazy golden orange with a lasting white head and good lacing.  Funky peach, apricot, earth, yeast, mild vinegar and brett.  Medium carb and body, creamy champagne texture.  Lingering funky finish.  Delicious.
# User Names:
# TheWhaleNorman
# hauxe
# 2OLD4BS
# Maverick34
# IPAMaestro32
# Finn
# jonas
# bdleedahl
# WareHavUBean
# thespiros
# kolemkoukolem
# sulawang
# ineedbeer
# MadRobin
# Bacchus66
# http://www.ratebeer.com/beer-ratings/1/3/
# Beer Names:
# Bell's Hop Grandslam
# North Brewing Co Big House Waltz
# Ommegang Hennepin
# Neon Raptor Centaur Army
# Superstition Black Berry White
# Superstition Blue Berry White
# Superstition Straw Berry White
# Westmalle Tripel
# North Coast Old Rasputin Russian Imperial Stout
# Incendiary DTKS: Blueberry Cherry Cobbler
# Deschutes Fresh Squeezed IPA
# Modern Times Wizard Blend
# Beachwood Blendery Dia De Los Mangos
# Jackie O's / Crooked Stave The Ties That Bind
# Inbound Fruit Of The Loop: Citrus IPA
# Beer Ratings:
# 4.6
# 4.6
# 4.6
# 4.5
# 4.6
# 4.9
# 4.9
# 5.0
# 5.0
# 4.6
# 5.0
# 4.5
# 5.0
# 4.5
# 4.6
# Brewery Locations:
# Comstock, Michigan
# Leeds, West Yorkshire
# Cooperstown, New York
# Nottingham, Nottinghamshire
# Prescott, Arizona
# Prescott, Arizona
# Prescott, Arizona
# Malle, Belgium
# Fort Bragg, California
# Winston-Salem, North Carolina
# Bend, Oregon
# San Diego, California
# Long Beach, California
# Athens, Ohio
# Minneapolis, Minnesota
# User Reviews:
# This is a heavy hitter. %10 IPA VERY hoppy but the aroma is the most inviting thing. Taste isn exceptional and almost deceiving for such a high percentage. Notes of eccentric citrus and bitter but not to the point of undrinkable. You really have to take your time with it and allow your pallet to have a break in between sips to really appreciate what it has to offer.
# Wow this is damn good. Right away when I opened the can I could smell tropical fruits for days and the taste didn't disappoint neither. Packed with tropical fruits such as mango, papaya, passion fruit and in come the peaches and honey dew melon. This is world class IPA!
# Anchor California Lager
# Great Divide Yeti Imperial Stout
# Beer Ratings:
# 3.9
# 4.1
# 3.8
# 3.9
# 4.3
# 4.5
# 3.8
# 3.5
# 4.2
# 5.0
# 3.8
# 4.0
# 3.4
# 4.7
# 4.0
# Brewery Locations:
# Kelheim, Bavaria
# Keighley, West Yorkshire
# Bermondsey, Greater London
# Long Beach, California
# Coalville, Leicestershire
# Freising, Bavaria
# Tampa, Florida
# Munich, Bavaria
# Bayreuth, Bavaria
# Kelheim, Bavaria
# Alpine, California
# Placentia, California
# Huddersfield, West Yorkshire
# San Francisco, California
# Denver, Colorado
# User Reviews:
# Golden, hazy, white beerhead with frothy, thick and lacing foam. Good retention. The aroma is hoppy, such as floral, fruity (kiwi, mango, banana) spices and somehow herbal. Medium sweetness, medium carbonation, medium bitterness, and smooth touch. Alcoholic warmth.
# Copper colour, creamy foam atop. Brown sugar/caramel, creamy, malts, bready, fruit/melon undertones... it really has all you need in a 'standard' bitter. Excellent example of the style.
# Bottle from M&S.  BB Aug 2021; Drank Jan 2020 - Very dark brown / black.  Small tan head.  Very malty, roasty malts, dark chocolate, coffee, liquorice.  Moderate hop bitterness.  Dried fruits, raisins.  Spicy.  Sweet-bitter dry roast chocolate and coffee malty hoppy fruity and spicy.  Dry burnt roast finish.  Enjoyed this.  Good one.  (2020-01)
# Creamy white good mostly lasting head. Yellow colour. Moderate malty and heavy hoppy aroma. Heavy bitter flavor. Long heavy bitter finish. Creamy palate.
# Bottled, 330ml from Pump it Up, Belper, Derbys. Deep dark chestnut with cream head. This is rich and smooth from the off, darkly roasted malts with a note of caramelisation, some sweet toffee'd notes, liquorice. Fruity tones come through, red port wine, grapes and fig flavours. Easy on the palate, notes of dry plum in the close. Loved it.
# Прекрасная немецкая пшеничка. Нефильтрованное, непастеризованное. Приятный богатый вкус. Рекомендую. Одно из моих фаворитов.
# Getting really tired of this sweet beers the dessert Brews. Nevertheless this is fairly decent and does taste like its name
# Конечно, я пробовал баночное, но такого восторга, как пишут об этом немецком пиве, не ощутил. Достаточно обычное пиво. Ничего выдающегося. На один раз. Ну может на два.
# Хорошая немецкая пшеничка. Нефильтрованное, непастеризованное. Хороший баланс. Единственный минус - достаточно высокая цена. Около 3 долларов за бутылку.
# Попробовал 12 сортов немецкого пива, бутылки и банки, но это -  однозначно фаворит. Воистину пиво, в  котором всё в меру - и сладость, и кислинка, и горечь. Ничего не убрать, ничего не добавить. Рекомендую всем!
# 12 fl oz can.
# Appearance: Almost clear bright gold, with a finger of white froth which persisted only for a minute.
# Aroma: Citrus hops plus rind and pine and woody notes.
# Taste: Light sweetness of citrus, over massive pine and resin bitterness.
# Mouthfeel: Medium bodied, very consistent, low to average carbonation.
# Overall: Big West Coast IPA with all the sharp bitterness and floral hoppy flavours.
# Bottle. Pours clear mahogany, small beige head, some lacing. Aroma is boozy, berries, vinous, bourbon, vanilla, cocoa, bakers chocolate. Flavor is fairly sweet, light plus bitter. Hot. Medium body. Total sipper. Basically port.
# Color naranja oscuro, turbia, translúcida. Espuma blanca de más de un dedo de espesor y media retención. Aroma a melocotón maduro y ligera resina que se intensifica rápidamente con la temperatura. Sabor a resina, melocotón y miel, final largo, resinoso, excesivo al llegar a mitad de toma, ligeramente seco, alcohol notable, cansino al atemperar y unirse a la resina. Textura semioleosa. Carbonatación media.
# Cerveza de color dorado y fina espuma blanca al servirse. Con un sútil olor a lúpulo y sabor a malta tostada, naranja y frutas. Tiene un final  seco y amargo muy agradable al paladar.
# Imperial stout de 9,5 % abv et 75 ebu, en format 35,5 cl.
# A noter qu'il est toujours très agréable de rencontrer le yéti en février,
# surtout quand les températures du jour et du lieu avoisinaient les 24° C.
# Mon exemplaire, de Denver, Colorado, était à 9 mois avant sa date.
# Couleur noir profond aux reflets marron grillé, à l'opacité très forte.
# Mousse brun roux foncé, soyeuse, stable à 2 mm.
# Arômes de cèdre, baies noires macérées en péket, chêne liège brûlé.
# 1ère bouche très souple, sur un bois brûlé de la plus belle manière …
# (si l'on peut dire, et sans être un pyromane ...)
# Arrière-bouche avec une impression de strong dry stout.
# 2ème bouche avec café serré, poivre, muscade, tabac brun.
# Arrière-bouche qui entre dans la complexité, avec une allégresse vive.
# Longueur qui trouve pas mal de zestes dans ce café taillé au couteau ..
# Jambes très huileuses, limite grasses, très longues.
# Levure boisée, vernissée, belle ligne.
# Alcool fort, plus haut que son niveau, il fait un 10,5 % tranquille,
# mais il se révèle un peu emprisonné sur la longueur …
# Il ne peut trouver d'autres issues aux saveurs, juste un peu "coincées".
# Finale intéressante, sans problème, mais oh combien discutable ..
# CONCLUSION : le yéti est un personnage séduisant (de loin ..), mais
# incontestablement excessif, dans tous les sens du terme, et donc si
# on est un biérophile averti, on ne va pas lui trouver de 5 à la cote,
# malgré les pages qui en sont remplies … Yéti soit qui mal y pense !!
# Moralité : grande division (divide) sur la présence de ce yéti .. à 24° C.
# (à noter aussi qu'il n'a reçu que des médailles d'argent et de bronze ...)
# (à noter enfin qu'il est conseillé avec du steak grillé .. on a compris !!)
# (8/4/8/4/16)
# User Names:
# ChungYunJi
# AWS9
# john44
# HenrikSoegaard
# imdownthepub
# v_douby
# drpimento
# v_douby
# v_douby
# v_douby
# the_beergery
# bytemesis
# ricardostercios
# alfonsochinchillarico
# corkyrory66
# http://www.ratebeer.com/beer-ratings/1/8/
# Beer Names:
# Modern Times Cosmic Entiity
# Horus Aged Ales Deepest Shade
# Westbrook Mexican Cake Imperial Stout
# Other Half Droppin' Millibars - Cacao Nibs, Coffee, Peanut Butter and Vanilla
# Perennial Maman (2019)
# Prairie Pirate Bomb!
# Jackie O's Perpetum - Cherry Vanilla
# Bas-Canada Double Los Tabarnacos - Mangue
# Brauerei Eichhorn Pils
# WeldWerks Beach Party Starter
# Brew By Numbers 10 Coffee Porter - Brazil Fazenda Santissimo
# Founders Barrel Aged CBS (Canadian Breakfast Stout)
# Theakston Old Peculier (Bottle)
# Three Notch'd KGB (Know Good Beer)
# Three Floyds Stone Feathers
# Beer Ratings:
# 4.5
# 4.5
# 4.9
# 4.5
# 4.5
# 4.8
# 4.5
# 4.7
# 4.5
# 4.7
# 4.5
# 4.5
# 5.0
# 4.5
# 5.0
# Brewery Locations:
# San Diego, California
# Oceanside, California
# Mount Pleasant, South Carolina
# Brooklyn, New York
# St. Louis, Missouri
# Tulsa, Oklahoma
# Athens, Ohio
# Gatineau, Quebec
# Hallstadt-Dörfleins, Bavaria
# Greeley, Colorado
# Bermondsey, Greater London
# Grand Rapids, Michigan
# Masham, North Yorkshire
# Charlottesville, Virginia
# Munster, Indiana
# User Reviews:
# This was great.  Black with mocha head.  Smooth and thick.  Vanilla comes through the most, with light roast (could have bet there was coffee in here too), cocoa, deep malts.  Very nice!
# Black as my soul with mocha head.  Thick but NO sign of 15.5%, in part because the roasted malts hazelnut and awesome JBM coffee (my personal favorite) obscure the alcohol.  Great great great dessert beer.  4.5-
# Color negro, opaca. Un dedo de espuma marrón con buena retención. Aroma a malta tostada, café chocolate negro, canela y notas de guindilla. Gusto en la misma línea del aroma, añadiría vainilla y avena, bastante láctea y el chili habanero lo tiene bastante pronunciado. Cuerpo oleoso. Una maravilla de Imperial Stout, la edición anterior tenía la canela mucho más marcada y en esta el habanero manda, obligado su elaboración anual.
# 13.2%ABV.   Imperial stout.
#
# Tapped out black.  40°SRM.
#
# Nose has aromas of earth, wood, fire.  There are elements of raw flour, wheat dust, dry hay as well which for me is totally attractive for a stout, which is so rare these days. It’s probably the PB2 that’s giving it the depth of earthy aroma. This is the aroma that suggest wet rotting logs, a compost heap, and fresh turned earth.  The nose has a bit of umami funk that suggest raw soy sauce.
#
# Mouthfeel is full and juicy with watered honey.  Low-moderate carbonation.  There is a bit of a carbonic tingle on the palate.
#
# Palate has flavors peanut butter and jelly.  There are herbal flavors suggesting licorice and lineament. There is nice base flavor peanut like a nice peanut butter sandwich or a Thai satay peanut sauce.  There are ample roasty flavors that suggest black coffee, espresso, charcoal and burnt ends.
#
# Hop flavors are woody with a hint of pine resin.
#
# Finish is surprisingly brief and clean with a hint of umami that suggests dashi, bonito flakes or soy.
#
# Overall, a big complex imperial stout that’s not like any other peanut butter concoction. This iteration seems to have gone umami, funky, and earthy instead of creamy, sweet, and boring.
# 750 ml bottle from the brewery. Weird to change the blend so dramatically in year 6 of this beer. Pours a deep, dark, inky and basically opaque brown with virtually no head. The liquid leaves thick legs in the glass as it goes down, too. Notes of vanilla, chocolate, caramel, brown sugar, oak, bourbon, dark dried fruits, and molasses. Medium-full bodied, with low to modest carbonation and a sweet, slick, rich, warming, coating mouthfeel in great balance. It's great. Not quite to the level of TWCP Maman but slightly better than previous vintages.
# Holy hell, what a beer...Cocoa, coffee, vanilla, black cherry, molasses, and anise, backed up by oak, chiles, roast, spice, and a lovely rum warmth. Amazing in its balance, never growing overly sweet or boozy, with a gentle, easygoing texture that would be surprising at 8%, much less friggin’ 15%. Amazing. The best Bomb! of them all. I want more. So much more.
# User Names:
# Hubson
# zebra
# hman43
# miloszd
# HopsTasty30
# AdamChandler
# TargetD
# YeastChecker49
# MarcoDL
# salonik
# salonik
# salonik
# Cybercat
# ResinousRates45
# PintMaster50
# http://www.ratebeer.com/beer-ratings/2/99/
# Beer Names:
# Zwiesel Dampfbier
# Collective Arts Collective Project: IPA Project #10
# Jever Pilsener
# Brew By Numbers 11 Session Black IPA
# Moerlein Big Hazy IPA
# Jever Fun
# Union Svetlo Pivo
# Miller Genuine Draft (MGD)
# Marston's Pale Ale
# Marston's Revisionist Irish Peated Ale
# Heubacher Weizenradler Naturtrüb
# Northpaw Blind Trust
# Abita Honey Suckle Saison
# Central City Beer League Powerplay
# Pabst Blue Ribbon
# Beer Ratings:
# 1.7
# 1.9
# 1.9
# 1.6
# 1.3
# 1.8
# 1.9
# 1.3
# 1.7
# 1.9
# 1.8
# 1.8
# 1.6
# 1.7
# 1.2
# Brewery Locations:
# Zwiesel, Bavaria
# Hamilton, Ontario
# Jever, Lower Saxony
# Bermondsey, Greater London
# Cincinnati, Ohio
# Jever, Lower Saxony
# Ljubljana, Slovenia
# Milwaukee                       , Wisconsin
# Burton-on-Trent, Staffordshire
# Burton-on-Trent, Staffordshire
# Heubach, Baden-Württemberg
# Port Coquitlam, British Columbia
# Abita Springs, Louisiana
# Surrey, British Columbia
# Los Angeles, California
# User Reviews:
# Dark amber with a fast dissipating head.
# Smell of nuts and sweet fruits. Taste of flowers, malt and a little soapy. Medium carbonation. Weak body.
# Tall can from grocery store. Smells fruity and well hopped, pours golden with ample head. A bit murky, but that could be stylistically appropriate. Thin and dry, with too little malt/sweetness to counter the hops. Found it too unpleasant to drink.
# Clear golden with a thin head.
# Strawy, hempy smell of hops. Bitter and dry, a bit too dry for my taste. High carbonation.
# Not my kind of beer.
# 440ml can, but 4 days out of date.  Murky dark brown. Aroma of dark malt and metallic notes.  Dark sugars in the flavour with damp malt.  Considering it had only just gone out of date, this beer was in a bad way.
# From a can you get a surprisingly clear liquid (considering the name, heheh) with a big foamy pour. It has just a very slight haze but no way is this hazy. No real offensive IPA smells in this one. Taste is big bad IPA of course and possibly it has a bit of an aged feeling to it. Date code is CMB1 9198 2361, whatever that means. Yes, big bitter IPA bullshit, like any other of the thousand ubiquitous IPA out there. What else can be said? NOTHING. Oh well, so goes the tick. Not impressed.
# Clear golden with a thin head.
# Strawy, hoppy smell. Very metallic taste with a malty finish. Mainly rather watery. Low carbonation.
# Zlatnozuta boja, bijela pjena srednje debljine, srednje trajna. Metalna aroma, veoma blago, skoro neprimjetno, arome trave i meda. Slabe gorčine, duzeg gorkog finiša. Vodene teksture, jake karbonizacije.
# Do nebe volající hnus, který jsem koupil jen tak ze zvědavosti, když jsem na něho natrefil v čadském Tescu.
# Cask at The Crown, Watford in 2012. Always was a naff Beer. Amber with a ring of white head. Aroma of sulphur, eggs, malt and raisins. Minimal flavour, with some grainy and mineral notes.
# Cask at the Kings Tun (JDW), Kingston in 2015. On paper this sounded good; the reality less so (although ‘Marston’s’ was a pretty big indicator). Hazy copper with an offwhite head. Lightest of peaty aromas; more sulphurous and grainy. Boiled sweets and apples in the flavour.
# Many thanks for this beer to Beerhunter111. Sweet aroma with lemons and lime. Sweet flavour with lemons and lime.
# Foggy gold body and okay foam, rotting armpit or maybe rancid lemons on the nose. Flavour is vague sweet hops overlaid with bitterness on the aftertaste. Alcohol is well hidden, but other than that this one is a miss.
# Yellow pour with zero head. Aroma is odd and medicinal. Has a weird flavor of unknown spices. Kind of tastes like a Band Aid smells. Strange numbness on the palate. Little to enjoy here. Bottle.
# Clear yellow body and bleach white foam, about what you'd expect. Smells of rotting socks found in the dumpster behind your house. Flavour is sweet lagery hops, vague hints of booze and a cloying tinny aftertaste. Kind of what you might expect from this beer, though the alcohol is reasonably well hidden.
# Barwa złot, klarowne. Cienka piana, bardzo szybko znika z kufla. Smak rzygowin, kwas, nieco słodu, generalnie odpycha. Posmak kwaśny. Bardzo słabe piwo, jeśli w ogóle można to nazwać piwem.
# User Names:
# ophone
# AllGrainExports40
# ophone
# Beese
# cheap
# ophone
# BojanM
# z87
# Beese
# Beese
# Mariusz
# DeanF
# pkbites
# DeanF
# kaziopiwosz
# http://www.ratebeer.com/beer-ratings/7/100/
# Beer Names:
# The Kernel Export Stout (Raspberry)
# Oettinger Export
# The Kernel Export Stout (Raspberry)
# Fort Point Animal
# Fownes Korvak's Demise
# Coronado Marine Dream
# Mondo / Gipsy Hill About Time
# Mondo / Gipsy Hill About Time
# Davenports Original Bitter (Cask)
# Davenports Original Bitter (Cask)
# Perlenbacher Premium Pils /  Bier
# Distillerie Fils du Roy Brut
# Alesong / Bailey's Taproom Bailey's Joy
# Beachwood Hayabusa
# Nesher Beer
# Beer Ratings:
# 3.4
# 3.2
# 3.5
# 3.7
# 3.6
# 3.6
# 3.4
# 3.1
# 3.4
# 3.0
# 1.3
# 3.6
# 3.6
# 3.1
# 2.2
# Brewery Locations:
# Bermondsey, Greater London
# Oettingen, Bavaria
# Bermondsey, Greater London
# San Francisco, California
# Gornal, Dudley, West Midlands
# Coronado, California
# Battersea, Greater London
# Battersea, Greater London
# Smethwick, West Midlands
# Smethwick, West Midlands
# Neckarsulm, Baden-Württemberg
# Petit-Paquetville, New Brunswick
# Eugene, Oregon
# Long Beach, California
# Netanya, Israel
# User Reviews:
# 7.3%. På GBBF Winter 2020 i Birmingham. Spandert av BeerViking. Delt med ham & Rune. Svart. Mokkafarget filmskum. Aroma av sjokolade & bær. Bringebæra dominerer smaken. Tørr bæraktig avslutning.
# I don't think is that bad as everyone thinks, not the best beer on earth but not a bad taste and a really low price.
# Keykeg at GBBF Winter 2020 and 7.3%, black with a fine crema and a berry-tangy nose. Dark, dry and roasted, with a tart edge. Notes of ashy coffee, a light fruity sweetness, then more burnt ash.
# Can from Citysuper at home. Deep golden transparent pour with puffy white head. Aroma is strong biscuit malt and deep resin hop. Taste is similar. Earthy bitterness, with some dank tropical mango. Biscuit malt. Lightly fizzy palate with fine carbonation. Bitter bite on finish, some alcohol warmth. Might be SF connection, but this seems related to an amped up, very slightly tropical Anchor IPA. Not bad at all.
# På GBBF Winter 2020 i Birmingham. Delt med Rune. Svart. Lavt mokkafarget skum. Lakrisaroma. Smaken balansert. Sjokolade. Lakris. Røstet malt. Tørr avslutning. Kakao. Av de bedre.
# Shared pint can poured to snifters showing a cloudy, straw color, with a decent layer of soft white froth, and a tight array of spots & streaks as lacing. The nose was ripe & dank, with expressive pineapple, citrus, and pit fruit. Medium bodied, with good carbonation, the taste was similar, adding complementary tartness & tanginess, soft creaminess, and appropriate, citrusy bitterness to match.
# Cask at GBBF Winter 2020, golden with vanilla and raspberry on the nose, then full bodied, sweet and strong, odd yet very drinkable.
# På GBBF Winter 2020 i Birmingham. Delt med Rune. Gusjegulbrun. God fersken/plommearoma. Smaken mango. Vanilje. Bra - men vel søt.
# Cask at GBBF Winter 2020, glowing brown with a lasting white head, 4.2%, fruity malty nose with hints of red fruit, sweet and herbal bitter, nice balance.
# På GBBF Winter 2020 i Birmingham. Spandert av BeerViking. Mørk gylden. Lett fruktaroma. Smaken tørket frukt. Litt sherrypreg. Tørr avslutning.
# Pale yellow color, fast dissapearing foamy white head.
# Sweet aroma, reminds me of corn, though it does not contain any. Taste is lightly malty, lightly bitter, light bodied with medium carbonation. Not bad for its price for hot summer days, but nothing really special going on here.
#
# One common trend I ca say about this brewer is sometimes, you’re not sure what you’re drinking. Is this one a brut, a sour, I would put it more in the malted wine category. Tastes close to a white wine, which is interesting.
# Shared 16.9 oz. bottle that was cellared a couple of years, poured to snifters showing a black/brown hue, with a presentable layer of brownish tan froth, and foamy spots & strands of lacing. The nose was roasted, malty, and freezer burn scent, with cocoa, dark caramel, slight dark fruit, and vanilla revealed upon warming. Medium+ bodied, with fair carbonation, the taste was similar, sweet, with the "back of the freezer" vanilla ice cream character diminishing to a harmless level, somewhat hidden alcohol, and adding some roasted & earthy bitterness, but no noticeable coconut. Showed a little age, but tasty enough.
# Draft. A golden beer with a huge white head. The aroma has notes of straw, minirals, and malt. The flavor is sweet with notes of straw, malt, and brewing cereal, leading to a bitter finish.
# (Bottle) Pale amber with huge thick white head. Grain aroma. Light body and fizzy. Watery, metallic, unpleasant. Pretty nasty.
# User Names:
# Finn
# tonigranota
# BeerViking
# HKdIPA
# Finn
# tmoreau
# BeerViking
# Finn
# BeerViking
# Finn
# Maltmonster
# azzurro
# tmoreau
# Ungstrup
# Pyobon

# %%
# just need the new and anomalous cleaned

# %%
# beers =  np.array([beers])
# ratings = np.array([ratings])
# locations = np.array([locations])
# reviews =  np.array([reviews])
# users =  np.array([users])
# dataset = pd.DataFrame({'Beer Names':beers[0,:], 'Rating':ratings[0,:], 'Locations':locations[0,:],'Reviews':reviews[0,:], 'Users':users[0,:]})
# print(dataset)
# dataset.to_csv('CleanBeerScrape1.csv', index=False)

# %%
print(len(beers))
# Out:
# 1500
