# %%
import requests
import sqlalchemy
import numpy as np 
import urllib.request
from bs4 import BeautifulSoup
import re
import csv
import unicodedata
import pandas as pd
import numpy as np

# %%
response = requests.get('https://www.ratebeer.com/beer-ratings/')

# %%
response.headers
# Out:
# {'Date': 'Fri, 07 Feb 2020 01:21:16 GMT', 'Content-Type': 'text/html;charset=UTF-8,text/html;charset=UTF-8', 'Transfer-Encoding': 'chunked', 'Connection': 'keep-alive', 'Set-Cookie': '__cfduid=db6c2729c23a88924a6baa4522c2183c71581038475; expires=Sun, 08-Mar-20 01:21:15 GMT; path=/; domain=.ratebeer.com; HttpOnly; SameSite=Lax; Secure, legacy_session=SCDQTSDQ/EGMFJMACLBBNDIAKOILEMGED; path=/; HttpOnly', 'Cache-Control': 'private', 'X-Powered-By': 'ASP.NET', 'X-Frame-Options': 'SAMEORIGIN', 'X-XSS-Protection': '1; mode=block', 'CF-Cache-Status': 'DYNAMIC', 'Expect-CT': 'max-age=604800, report-uri="https://report-uri.cloudflare.com/cdn-cgi/beacon/expect-ct"', 'Server': 'cloudflare', 'CF-RAY': '56118bc8ce94e71c-EWR', 'Content-Encoding': 'gzip'}

# %%
response.headers['Content-Type']
# Out:
# 'text/html;charset=UTF-8,text/html;charset=UTF-8'

# %%
URL = 'https://www.ratebeer.com/beer-ratings/'
r = requests.get(URL) 
  
soup = BeautifulSoup(r.content, 'html5lib') 
print(soup.prettify())
# Out:
# <html>
#  <head>
#   <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
#   <title>
#    Beer Reviews - The latest beer reviews - Most Recent
#   </title>
#   <meta content="The latest beer reviews from RateBeer, the largest collection of beer reviews in the world." name="description"/>
#   <meta content="beer, beer reviews, ratebeer, craft beer" name="keywords"/>
#   <link href="/css/inc_bubbles.css" rel="stylesheet" type="text/css"/>
#   <link href="/tags/tags.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/jquery-ui-1.9.2.custom.css" rel="stylesheet" type="text/css"/>
#   <link href="/css/brewer_tooltip.css" rel="stylesheet" type="text/css"/>
#   <!-- Optimize displays variants to your website visitors
# by modifying the DOM (Document Object Model).
# In some instances, changes are made to elements that
# are already visible to the end user.
# These visible changes are referred to as page flicker.
#
# One of the most effective ways to mitigate the risk
# of page flicker when loading Optimize is to temporarily
# hide the page while the Optimize container loads.
# This can be accomplished by adding the page-hiding snippet
# as the first script on your page(s) – after the <meta charset>
# declarations and before your Optimize, Analytics and/or Tag Manager tags.
#
# GTM-K6BZD7 is our TGM web container id -->
#   <style>
#    .async-hide { opacity: 0 !important}
#   </style>
#   <script>
#    (function(a,s,y,n,c,h,i,d,e){s.className+=' '+y;
# h.end=i=function(){s.className=s.className.replace(RegExp(' ?'+y),'')};
# (a[n]=a[n]||[]).hide=h;setTimeout(function(){i();h.end=null},c);
# })(window,document.documentElement,'async-hide','dataLayer',2000,{'GTM-K6BZD7':true});
#   </script>
#   <!-- Google Tag Manager -->
#   <script>
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-K6BZD7');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script type="text/javascript">
#    window.siteURL='https://www.ratebeer.com';window.auth0ClientID='vy3vQxKFXvMyXTjddkMiDJAUFucb8vdu';
#   </script>
#   <meta content="EN" http-equiv="content-language"/>
#   <link href="/favicon.ico" rel="shortcut icon"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="index,follow" name="robots"/>
#   <meta content="general" name="rating"/>
#   <meta content="RateBeer" property="og:site_name"/>
#   <meta content="website" property="og:type"/>
#   <meta content="https://s3-us-west-2.amazonaws.com/ratebeer-mobile-app-bucket/RateBeerAppLogo.png" property="og:image"/>
#   <meta content="13411472" property="twitter:account_id"/>
#   <meta content="summary" name="twitter:card"/>
#   <meta charset="utf-8" content="text/html;" http-equiv="Content-Type"/>
#   <meta content="@ratebeer" name="twitter:site"/>
#   <meta content="@ratebeer" name="twitter:creator"/>
#   <meta content="https://www.ratebeer.com" name="twitter:domain"/>
#   <!-- JS Global Compulsory, 2nd -->
#   <script src="//code.jquery.com/jquery-2.2.4.min.js">
#   </script>
#   <script crossorigin="anonymous" integrity="sha384-0mSbJDEHialfmuBBQP6A4Qrprq5OVfW37PRR3j5ELqxss1yVqOtnepnHVP9aJ7xS" src="//maxcdn.bootstrapcdn.com/bootstrap/3.3.6/js/bootstrap.min.js">
#   </script>
#   <!-- Latest compiled and minified CSS, 1st -->
#   <link href="//maxcdn.bootstrapcdn.com/font-awesome/4.3.0/css/font-awesome.min.css" rel="stylesheet"/>
#   <link crossorigin="anonymous" href="//maxcdn.bootstrapcdn.com/bootstrap/3.3.6/css/bootstrap.min.css" integrity="sha384-1q8mTJOASx8j1Au+a5WDVnPi2lkFfwwEAa8hDDdjZlpLegxhjVME1fgjWPGmkzs7" rel="stylesheet"/>
#   <link href="/css/custombs.css" rel="stylesheet"/>
#   <link href="//fonts.googleapis.com/css?family=Fira+Sans:700&amp;subset=latin,latin-ext" rel="stylesheet" type="text/css"/>
#   <link href="//fonts.googleapis.com/css?family=Roboto" rel="stylesheet"/>
#   <script src="/js/ihavecookies.js">
#   </script>
#   <script async="async" src="//www.googletagservices.com/tag/js/gpt.js">
#   </script>
#   <script>
#    var googletag = googletag || {};
#   googletag.cmd = googletag.cmd || [];
#   </script>
#   <script>
#    // Define a size mapping object. The first parameter to addSize is
# // a viewport size, while the second is a list of allowed ad sizes.
#
# googletag.cmd.push(function() {
#    var mapping = googletag.sizeMapping().
#   addSize([1280, 0], [[970, 90], [728, 90], [468, 60], [300, 250]]).
# //desktop big
#   addSize([1024, 0], [[970, 90], [728, 90], [468, 60], [250, 250], [200,
# 200]]). //desktop
#   addSize([768, 0], [[728, 90], [468, 60]]). //laptop
#   addSize([480, 0], [468, 60]). //tablet
#   addSize([420, 0], [320, 50]). //tablet
#   addSize([0, 0], [[320, 50]]). //others
#   build();
#
# // Define the GPT slot
#
#     googletag.defineSlot('/3397136/Large-Leaderboard-GPT', [970, 90],
# 'div-gpt-ad-1474465396265-0').defineSizeMapping(mapping).addService(googletag.pubads());
#     googletag.defineSlot('/3397136/GPT-Medium-Rectangle', [[250, 250],
# [300, 250], [200, 200]],
# 'div-gpt-ad-1474477890595-0').addService(googletag.pubads());
#     googletag.defineSlot('/3397136/GPT-Low-Leaderboard', [970,
# 90], 'div-gpt-ad-1474478067303-1').defineSizeMapping(mapping).addService(googletag.pubads());
#
#     googletag.pubads().enableSingleRequest();
#     googletag.pubads().setTargeting("test","responsive");
# // Start ad fetching
#    googletag.enableServices();
#  });
#   </script>
#   <style>
#    #html * {   font-family: 'Roboto', sans-serif;}
# h1, h3{font-family: 'Fira Sans', sans-serif !important; margin-bottom: 2px;}
#
# /* reset webkit search input browser style */
# input {
# 	outline: none;
# }
# input[type=search] {
# 	-webkit-appearance: textfield;
# 	-webkit-box-sizing: content-box;
# 	font-family: inherit;
# 	font-size: 100%;
# }
# input::-webkit-search-decoration,
# input::-webkit-search-cancel-button {
# 	display: none; /* remove the search and cancel icon */
# }
#
# /* search input field */
# input[type=search] {
# 	background: #ededed;
# 	border: solid 1px #ccc;
# 	padding: 9px 10px 9px 10px;
# 	width: 95px;
#
# 	-webkit-border-radius: 10em;
# 	-moz-border-radius: 10em;
# 	border-radius: 10em;
#
# 	-webkit-transition: all .3s;
# 	-moz-transition: all .3s;
# 	transition: all .3s;
# }
# input[type=search]:focus {
# 	width: 85%;
# 	background-color: #fff;
# 	border-color: #6dcff6;
#
# 	-webkit-box-shadow: 0 0 5px rgba(109,207,246,.5);
# 	-moz-box-shadow: 0 0 5px rgba(109,207,246,.5);
# 	box-shadow: 0 0 5px rgba(109,207,246,.5);
# }
#
# /* placeholder */
# input:-moz-placeholder {
# 	color: #999;
# }
# input::-webkit-input-placeholder {
# 	color: #999;
# }
# .norman {margin-top: 8px; margin-bottom: 8px; margin-right: 3px;}
#
# #rbbody{max-width: 1600px; margin: auto;}
# #.rblogo {max-height:48px; margin: 10px 0px 10px 20px;border:0;}
# .logo {margin: 10px 0px 0px 20px;border:0;}
# .mobile-nav-menu{position: absolute; right: 0;text-align:right;}
# #.browser-nav-menu{padding-right:40px;}
# .header-leaderboard{border: 1px solid #e0e0e0; width: 100%; margin: auto; text-align: center; white-space:nowrap;min-height: 60px;margin: 0px 0px 10px 0px;}
#
#  /* Cookie Dialog */
#     #gdpr-cookie-message {
#         position: fixed;
#         right: 30px;
#         bottom: 30px;
#         max-width: 375px;
#         background-color: #e0e0e0;
#         padding: 20px;
#         border-radius: 5px;
#         box-shadow: 0 6px 6px rgba(0,0,0,0.25);
#         margin-left: 30px;
#         font-family: system-ui;
#     }
#     #gdpr-cookie-message h4 {
#         color: #1f8cbb;
#         font-family: 'Roboto', sans-serif;
#         font-size: 18px;
#         font-weight: 500;
#         margin-bottom: 10px;
#     }
#     #gdpr-cookie-message p {
#         color: #333333;
#         font-size: 15px;
#         line-height: 1.5em;
#     }
#     #gdpr-cookie-message p:last-child {
#         margin-bottom: 0;
#         text-align: right;
#     }
#     #gdpr-cookie-message a {
#         color: #;
#         text-decoration: none;
#         font-size: 15px;
#         padding-bottom: 2px;
#         border-bottom: 1px dotted rgba(255,255,255,0.75);
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message a:hover {
#         color: #e0e0e0;
#         border-bottom-color: var(--blue);
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message button {
#         border: none;
#         background: #1f8cbb;
#         color: white;
#         font-family: 'Roboto', sans-serif;
#         font-size: 15px;
#         padding: 7px;
#         border-radius: 3px;
#         margin-left: 15px;
#         cursor: pointer;
#         transition: all 0.3s ease-in;
#     }
#     #gdpr-cookie-message button:hover {
#         background: #1f8cbb;
#         color: #ffffff;
#         transition: all 0.3s ease-in;
#     }
#   </style>
#   <script type="text/javascript">
#    $(document).ready(function() {
# 	$('body').ihavecookies({
#   title: "Cookies & Privacy",
#   message: "We use cookies to offer you a better browsing experience. This website can only display its content once you accept the sites cookies. Additionally, we use tracking technologies to analyze your use of this website, to deliver advertisements tailored to your interests by cooperating with ad networks, ad serving vendors and similar services. We may collect information about your online activity (e.g., the sites and pages you have visited) through tracking technologies such as cookies, tracking pixels and similar devices in order to deliver ads and online services that are relevant to you.",
#   expires: 365 // 365 days
#         });
#     });
#   </script>
#  </head>
#  <body>
#   <div id="rbbody">
#    <!--
# <div class="container">
#     <div class="col-xs-12 col-xl-12 alert alert-danger">
#         RateBeer is scheduled for maintainence from <b>08:00 UTC - 09:00 UTC</b>
#     </div>
# </div>
# -->
#    <div class="row" style="margin-left: 0; margin-right: 0;">
#     <div class="col-xs-4 col-sm-4 col-md-4 col-lg-3">
#      <a href="/">
#       <img alt="RateBeer" class="img-responsive rblogo" height="38" src="/images/logos/rblogo0316.png" width="160"/>
#      </a>
#     </div>
#     <div class="col-xs-4 col-sm-5 col-md-4 col-lg-6 text-center">
#      <form action="/search" class="navbar-form" method="GET" name="search" role="search" style="margin-top: 10px;">
#       <input name="beername" placeholder="Search" type="search"/>
#      </form>
#     </div>
#     <div class="col-xs-4 col-sm-3 col-md-2 col-lg-3 text-right">
#      <div class="norman">
#       <a class="btn btn-default" data-auth0="">
#        Login/Sign Up
#       </a>
#      </div>
#     </div>
#    </div>
#    <nav class="navbar navbar-default" role="navigation">
#     <!-- Brand and toggle get grouped for better mobile display -->
#     <div class="navbar-header">
#      <button class="navbar-toggle" data-target="#bs-example-navbar-collapse-1" data-toggle="collapse" type="button">
#       <span class="sr-only">
#        Toggle navigation
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#       <span class="icon-bar">
#       </span>
#      </button>
#     </div>
#     <!-- Collect the nav links, forms, and other content for toggling -->
#     <div class="collapse navbar-collapse" id="bs-example-navbar-collapse-1">
#      <ul class="nav navbar-nav">
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         Beer
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/top">
#           Top 50
#          </a>
#         </li>
#         <li>
#          <a href="/beerstyles/">
#           Beer Styles
#          </a>
#         </li>
#         <li>
#          <a href="/tag/showall/">
#           Beer Tags
#          </a>
#         </li>
#         <li>
#          <a href="/beer-ratings/">
#           Recent Ratings
#          </a>
#         </li>
#         <li>
#          <a href="/breweries/">
#           Breweries
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/beerstyles/abbey-dubbel/71/">
#           Top By Style
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/BestInMyArea.asp?CountryID=213&amp;StateID=5">
#           Top By Region
#          </a>
#         </li>
#        </ul>
#       </li>
#       <li>
#        <a href="https://community.ratebeer.com">
#         Forums
#        </a>
#       </li>
#       <li>
#        <a href="/places/browse/">
#         Places
#        </a>
#       </li>
#      </ul>
#      <ul class="nav navbar-nav navbar-right">
#       <li>
#        <a href="/events">
#         Events
#        </a>
#       </li>
#       <li>
#        <a href="/users">
#         Community
#        </a>
#       </li>
#       <li class="dropdown">
#        <a class="dropdown-toggle" data-toggle="dropdown" href="#">
#         More
#         <b class="caret">
#         </b>
#        </a>
#        <ul class="dropdown-menu">
#         <li>
#          <a href="/search.php">
#           <i class="glyphicon glyphicon-search">
#           </i>
#           Advanced Search
#          </a>
#         </li>
#         <li>
#          <a href="/AboutPremium_join.asp">
#           Buy Premium Membership
#          </a>
#         </li>
#         <li class="divider">
#         </li>
#         <li>
#          <a href="/about.asp">
#           About Us
#          </a>
#         </li>
#         <li>
#          <a href="/ratebeerbest/">
#           RateBeer Best
#          </a>
#         </li>
#        </ul>
#       </li>
#      </ul>
#     </div>
#     <!-- /.navbar-collapse -->
#    </nav>
#    <!--script type="text/javascript" src="//ajax.googleapis.com/ajax/libs/jquery/1.7/jquery.min.js"></script-->
#    <script src="../javascript/jquery-ui-1.9.2.custom.min.js" type="text/javascript">
#    </script>
#    <script>
#     $( function() {
#     $( document ).tooltip({
#       position: {
#         my: "center bottom-20",
#         at: "center top",
#         using: function( position, feedback ) {
#           $( this ).css( position );
#           $( "<div>" )
#             .addClass( "arrow" )
#             .addClass( feedback.vertical )
#             .addClass( feedback.horizontal )
#             .appendTo( this );
#         }
#       }
#     });
#   } );
#    </script>
#    <style>
#     .table {
#     border-bottom:0px !important;
# }
# .table th, .table td {
#     border: 0px !important;
# }
#    </style>
#    <div class="container-fluid">
#     <div class="col-xl-offset-2 col-xl-8 col-lg-10 col-lg-offset-1 col-md-12">
#      <ul class="pull-left breadcrumb">
#       <li>
#        <a href="/">
#         Home
#        </a>
#       </li>
#       <li>
#        Ratings
#       </li>
#      </ul>
#      <div class="clearfix">
#      </div>
#      <h1>
#       Beer Ratings: Most Recent
#      </h1>
#      <p>
#       <small>
#       </small>
#      </p>
#      <div class="col-xs-12 col-sm-12 col-md-9 col-lg-9 col-xl-9">
#       <br/>
#       <ul class="nav nav-tabs hidden-xs">
#        <li class="active" role="presentation">
#         <a href="/beer-ratings/">
#          Recent
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/5/">
#          New
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/4/">
#          Favs
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/1/">
#          Raves
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/2/">
#          Rants
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/beer-ratings/3/">
#          Anomalous
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/AboutPremium.asp">
#          <span role="premie">
#           P
#          </span>
#          Friends
#         </a>
#        </li>
#        <li class="" role="presentation">
#         <a href="/AboutPremium.asp">
#          Local
#         </a>
#        </li>
#       </ul>
#       <div class="dropdown hidden-sm hidden-md hidden-lg hidden-xl">
#        <button aria-expanded="true" aria-haspopup="true" class="btn btn-default dropdown-toggle form-control" data-toggle="dropdown" id="dropdownMenu1" type="button">
#         Show Ratings
#         <span class="caret">
#         </span>
#        </button>
#        <ul aria-labelledby="dropdownMenu1" class="dropdown-menu">
#         <li class="active" role="presentation">
#          <a href="/beer-ratings/">
#           Recent
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/1/">
#           Raves
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/2/">
#           Rants
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/3/">
#           Anomalous
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/4/">
#           High
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/beer-ratings/5/">
#           New
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/AboutPremium.asp">
#           <span role="premie">
#            P
#           </span>
#           Friends
#          </a>
#         </li>
#         <li class="" role="presentation">
#          <a href="/AboutPremium.asp">
#           Local
#          </a>
#         </li>
#        </ul>
#       </div>
#       <br/>
#       <table class="table" style="padding-right:20px;padding-top:100px;">
#        <tbody>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/dogfish-head-american-beauty-hazy-ripple-ipa/785704/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_198.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_785704.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/dogfish-head-american-beauty-hazy-ripple-ipa/785704/10229/" style="font-size:20px; font-weight:bold;">
#            Dogfish Head American Beauty Hazy Ripple IPA
#           </a>
#           <span class="uas">
#            3.3
#           </span>
#           <div>
#            <a href="/brewers/dogfish-head-brewery/198/">
#             Dogfish Head Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Milton, Delaware
#            </span>
#           </div>
#           <div style="color:#666;">
#            On Tap.  Classic hazy light golden straw color. Soft wheaty floral, tropical aromas and fa=lavors.  Flowery even.  Soft pillowy finish.  A littel allspice or clove at the end. A bit fancy and pretentious but pleasant and soft.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/10229/">
#             <span style="color:#8b8b8b;">
#              IndianaRed
#             </span>
#            </a>
#            <a href="/user/10229/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_IndianaRed.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/iowa-3rd-street-stout/729861/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_26914.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_729861.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/iowa-3rd-street-stout/729861/392434/" style="font-size:20px; font-weight:bold;">
#            Iowa 3rd Street Stout
#           </a>
#           <span class="uas">
#            3.6
#           </span>
#           <div>
#            <a href="/brewers/iowa-brewing-company/26914/">
#             Iowa Brewing Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Cedar Rapids, Iowa
#            </span>
#           </div>
#           <div style="color:#666;">
#            12oz can from Windsor Hy-Vee, in a Sam Smith pint glass. Aromas of vanilla, caramel, malted barley, wet grass, forest floor, milk chocolate and dark-roast coffee. Pours deep chocolate brown with one finger of foamy chocolate head that dissipates rapidly. Opens crisp and acidic for its style with creamy sweet roast taking charge on the mid-palate and a long roasty and somewhat hoppy finish. Medium- to full-bodied with mild stickiness and astringency in the end, just a touch. Not bad! Nose is very appealing, flavor is a bit generic, but the price is great and it's very drinkable.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/392434/">
#             <span style="color:#8b8b8b;">
#              saltyseadog
#             </span>
#            </a>
#            <a href="/user/392434/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_saltyseadog.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/ninkasi-megalodom/495906/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_6779.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_495906.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/ninkasi-megalodom/495906/10229/" style="font-size:20px; font-weight:bold;">
#            Ninkasi Megalodom
#           </a>
#           <span class="uas">
#            2.9
#           </span>
#           <div>
#            <a href="/brewers/ninkasi-brewing-company-legacy-breweries/6779/">
#             Ninkasi Brewing Company (Legacy Breweries)
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Eugene, Oregon
#            </span>
#           </div>
#           <div style="color:#666;">
#            On Tap  Clear medium golden with a  lasting dense white head. Strang clean hard biting piney and somewhat chemically hop bitterness.   Clean dry finish
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/10229/">
#             <span style="color:#8b8b8b;">
#              IndianaRed
#             </span>
#            </a>
#            <a href="/user/10229/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_IndianaRed.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/becks/703/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_112.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_703.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/becks/703/703278/" style="font-size:20px; font-weight:bold;">
#            Beck's
#           </a>
#           <span class="uas">
#            2.1
#           </span>
#           <div>
#            <a href="/brewers/brauerei-beck-co-beck39s/112/">
#             Brauerei Beck &amp; Co. - Beck's
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Bremen, Bremen
#            </span>
#           </div>
#           <div style="color:#666;">
#            My old man's go to. Very important to get the imported variant rather than the domestically brewed stuff. Although, it's not really that great and I'd have a few choices over it at the price point. A bit bolder than the regular macro lager, but otherwise quite standard.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/703278/">
#             <span style="color:#8b8b8b;">
#              fellers
#             </span>
#            </a>
#            <a href="/user/703278/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_fellers.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/gigantic-massive-cognac-barrel/800136/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_14535.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_800136.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/gigantic-massive-cognac-barrel/800136/1966/" style="font-size:20px; font-weight:bold;">
#            Gigantic Massive! - Cognac Barrel
#           </a>
#           <span class="uas">
#            4.2
#           </span>
#           <div>
#            <a href="/brewers/gigantic-brewing/14535/">
#             Gigantic Brewing
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Portland, Oregon
#            </span>
#           </div>
#           <div style="color:#666;">
#            Bottle from Bine &amp; Vine. Pours hazy ruddy brown with a slight beige head. Aroma of slight musty oak and brandy. Note: This should also be placed in Calvados barrels. There's medium dark fruit notes. Can't parse out malt. There is heat mixed in the aroma. Full bodied. Flavor is musty oak, brandy, red berries, roasty malt, brown sugar. Heat is detectable, but so subtle it has to be paid attention to - cause the overall flavors really obscure it. Not dry, but something, perhaps heat, tends to balance out the malt. This is excellent.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/1966/">
#             <span style="color:#8b8b8b;">
#              bhensonb
#             </span>
#            </a>
#            <a href="/user/1966/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_bhensonb.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/kona-island-colada-cream-ale/807702/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_435.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_807702.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/kona-island-colada-cream-ale/807702/341820/" style="font-size:20px; font-weight:bold;">
#            Kona Island Colada Cream Ale
#           </a>
#           <span class="uas">
#            3.8
#           </span>
#           <div>
#            <a href="/brewers/kona-brewing-company-craft-brew-alliance-ab-inbev/435/">
#             Kona Brewing Company (Craft Brew Alliance - AB InBev)
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Kailua Kona, Hawaii
#            </span>
#           </div>
#           <div style="color:#666;">
#            Can smell the cream, pineapple and some coconut. Get mostly cream and some sweet pineapple. Decent.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/341820/">
#             <span style="color:#8b8b8b;">
#              Obfuscate
#             </span>
#            </a>
#            <a href="/user/341820/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_Obfuscate.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/heineken/37/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_9.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_37.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/heineken/37/703278/" style="font-size:20px; font-weight:bold;">
#            Heineken
#           </a>
#           <span class="uas">
#            1.3
#           </span>
#           <div>
#            <a href="/brewers/heineken-nederland/9/">
#             Heineken Nederland
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Zoeterwoude, Netherlands
#            </span>
#           </div>
#           <div style="color:#666;">
#            Another lame macro lager. Boring and watery. I don't know why people bother to import this into Australia when there are a billion beers like it already available.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/703278/">
#             <span style="color:#8b8b8b;">
#              fellers
#             </span>
#            </a>
#            <a href="/user/703278/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_fellers.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/spring-house-taang/808429/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_9382.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_808429.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/spring-house-taang/808429/93638/" style="font-size:20px; font-weight:bold;">
#            Spring House Taang!
#           </a>
#           <span class="uas">
#            3.7
#           </span>
#           <div>
#            <a href="/brewers/spring-house-brewing-company/9382/">
#             Spring House Brewing Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Conestoga, Pennsylvania
#            </span>
#           </div>
#           <div style="color:#666;">
#            16 oz. Aroma is Smarties, Tang, oranges, bready. Pours hazy golden with large-ish chunks of sediment floating around; has a one finger bone-white head with decent retention. Taste has a moderate pithy  bitterness, a light to moderate sweetness, with flavors of Tang and oranges, peel and pulp, vanilla. Not bad.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/93638/">
#             <span style="color:#8b8b8b;">
#              poisoneddwarf
#             </span>
#            </a>
#            <a href="/user/93638/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_poisoneddwarf.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/pipeworks-donut-soup/719022/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_10970.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_719022.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/pipeworks-donut-soup/719022/104701/" style="font-size:20px; font-weight:bold;">
#            Pipeworks Donut Soup
#           </a>
#           <span class="uas">
#            4.0
#           </span>
#           <div>
#            <a href="/brewers/pipeworks-brewing-company/10970/">
#             Pipeworks Brewing Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Chicago, Illinois
#            </span>
#           </div>
#           <div style="color:#666;">
#            16 ounce can.  Pours black with a decent tan head.  Aroma of chocolate, malt, vanilla, and coconut.  Taste is chocolate, vanilla, coconut, roasted malt, and a bit of coffee.  Nice to sip on.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/104701/">
#             <span style="color:#8b8b8b;">
#              RobertDale
#             </span>
#            </a>
#            <a href="/user/104701/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_RobertDale.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/maine-beer-zoe/120334/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_10659.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_120334.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/maine-beer-zoe/120334/48884/" style="font-size:20px; font-weight:bold;">
#            Maine Beer Zoe
#           </a>
#           <span class="uas">
#            4.1
#           </span>
#           <div>
#            <a href="/brewers/maine-beer-company/10659/">
#             Maine Beer Company
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Freeport, Maine
#            </span>
#           </div>
#           <div style="color:#666;">
#            500 ml. bottled 10/29/2019. Slightly foggy, chestnut brew with a creamy film of foam. Interesting aroma of pineapple upside-down cake with touches of cocoa, grapefruit and orange. Flavor has bread, orange, grapefruit, toffee, white pepper, toasted walnut and a touch of coffee. Medium body has medium-high carbonation that's almost too much but remains smooth enough. Easy drinking balance that finishes nutty and dry.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/48884/">
#             <span style="color:#8b8b8b;">
#              nearbeer
#             </span>
#            </a>
#            <a href="/user/48884/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_nearbeer.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/robinsons-helles-lager-bier/801298/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_2784.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_801298.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/robinsons-helles-lager-bier/801298/137343/" style="font-size:20px; font-weight:bold;">
#            Robinsons Helles Lager Bier
#           </a>
#           <span class="uas">
#            2.5
#           </span>
#           <div>
#            <a href="/brewers/robinsons-family-brewery/2784/">
#             Robinsons Family Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Stockport, Greater Manchester
#            </span>
#           </div>
#           <div style="color:#666;">
#            Keg @ Castle Hotel, Manchester.  Golden with a creamy head.  It's certainly styled well and is crisp with a fair carbonation.  This one is for lager lovers only though.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/137343/">
#             <span style="color:#8b8b8b;">
#              ManVsBeer
#             </span>
#            </a>
#            <a href="/user/137343/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_ManVsBeer.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/kansas-avenue-ghostly-coyote/780622/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_1021.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_780622.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/kansas-avenue-ghostly-coyote/780622/137343/" style="font-size:20px; font-weight:bold;">
#            Kansas Avenue Ghostly Coyote
#           </a>
#           <span class="uas">
#            2.9
#           </span>
#           <div>
#            <a href="/brewers/hydes-brewery/1021/">
#             Hydes Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Salford, Greater Manchester
#            </span>
#           </div>
#           <div style="color:#666;">
#            Cask @ Abel Heywood, Manchester.  Blonde with a creamy head.  It's a very easy textured hoppy ale with some bitterness.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/137343/">
#             <span style="color:#8b8b8b;">
#              ManVsBeer
#             </span>
#            </a>
#            <a href="/user/137343/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_ManVsBeer.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/bells-light-hearted-ale/806428/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_232.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_806428.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/bells-light-hearted-ale/806428/341820/" style="font-size:20px; font-weight:bold;">
#            Bell's Light Hearted Ale
#           </a>
#           <span class="uas">
#            4.2
#           </span>
#           <div>
#            <a href="/brewers/bell39s-brewery/232/">
#             Bell's Brewery
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Comstock, Michigan
#            </span>
#           </div>
#           <div style="color:#666;">
#            An excellent example of a style I really enjoy. Light, crisp with a nice hop profile.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/341820/">
#             <span style="color:#8b8b8b;">
#              Obfuscate
#             </span>
#            </a>
#            <a href="/user/341820/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_Obfuscate.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/torrside-autonomy/804316/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_24653.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_804316.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/torrside-autonomy/804316/137343/" style="font-size:20px; font-weight:bold;">
#            Torrside Autonomy
#           </a>
#           <span class="uas">
#            2.8
#           </span>
#           <div>
#            <a href="/brewers/torrside-brewing/24653/">
#             Torrside Brewing
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             New Mills, Derbyshire
#            </span>
#           </div>
#           <div style="color:#666;">
#            Cask @ Jack In The Box at Mackie Mayor, Manchester.  Copper-red with a small head.  Has a bittered crisp hoppiness, but not that flavoursome.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/137343/">
#             <span style="color:#8b8b8b;">
#              ManVsBeer
#             </span>
#            </a>
#            <a href="/user/137343/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_ManVsBeer.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#         <tr>
#          <td align="center" valign="top">
#           <a href="/beer/pentrich-mild-chaos/808347/">
#            <img onerror="this.onerror=null;this.src='https://res.cloudinary.com/ratebeer/image/upload/w_40,h_40,c_thumb,r_max,d_brew_def.jpg/brew_21089.jpg';" src="https://res.cloudinary.com/ratebeer/image/upload/w_40/beer_808347.jpg" style="max-height:80px; margin: 0 auto;"/>
#           </a>
#          </td>
#          <td>
#           <a href="/beer/pentrich-mild-chaos/808347/137343/" style="font-size:20px; font-weight:bold;">
#            Pentrich Mild Chaos
#           </a>
#           <span class="uas">
#            2.9
#           </span>
#           <div>
#            <a href="/brewers/pentrich-brewing-co/21089/">
#             Pentrich Brewing Co.
#            </a>
#            <span class="small" style="color:#8b8b8b;">
#             Pentrich, Derbyshire
#            </span>
#           </div>
#           <div style="color:#666;">
#            Cask @ City Arms, Manchester.  Fuller hazed yellow-amber with a frothy head.  Has a citrus hoppiness, evident in both aroma and taste.
#           </div>
#           <span class="pull-right">
#            <a class="small" href="/user/137343/">
#             <span style="color:#8b8b8b;">
#              ManVsBeer
#             </span>
#            </a>
#            <a href="/user/137343/">
#             <img border="0" height="24" onerror="this.onerror=null;this.src='/images/icons/icon-user.png';" src="https://res.cloudinary.com/ratebeer/image/upload/w_60,h_60,c_thumb,r_max,g_face/user_ManVsBeer.jpg" width="24"/>
#            </a>
#           </span>
#           <br/>
#           <hr/>
#          </td>
#          <td align="center" valign="top">
#           <span class="uas">
#           </span>
#          </td>
#         </tr>
#        </tbody>
#       </table>
#       <div>
#        <div style="width: 200px; margin:0 auto;">
#         <div style="float: right;">
#          <a href="/beer-ratings/0/2/">
#           <img alt="next" border="0" src="/images/buttons/arrow-right.png"/>
#           Next
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#      <div class="col-xl-2 col-lg-3 col-md-3 col-sm-12 col-xs-12">
#       <div style="width:100%;">
#        <div id="tagside">
#         <a href="/beer/top-50/">
#          Top Rated Beer
#         </a>
#        </div>
#        <div style="padding: 10px;">
#         <span class="shortlist">
#          The overall Top 50 active beers as determined by our
#          <a href="/users">
#           worldwide community of beer raters
#          </a>
#         </span>
#         <br/>
#         <br/>
#        </div>
#        <script language="JavaScript">
#         <!-- Hide the script from old browsers --
# function goto(form) { var index=form.select.selectedIndex
# if (form.select.options[index].value != "0") {
# location=form.select.options[index].value;}}//-->
#        </script>
#        <form name="jump1">
#         <select class="form-control" id="menu" name="menu" onchange="location=document.getElementById('menu').value;" style="background-color: #E9F3Ff; color: #333; font-size: 13px; margin-bottom:6px; padding: 4px; border: 1px solid #B9DAF0;" value="GO">
#          <option value="0">
#           Best by Style
#          </option>
#          <option value="/beerstyles/altbier-sticke-alt/2/">
#           Altbier / Sticke Alt
#          </option>
#          <option value="/beerstyles/amber-lager-czech-polotmavy/115/">
#           Amber Lager - Czech / Polotmavý
#          </option>
#          <option value="/beerstyles/amber-lager-intl-vienna/36/">
#           Amber Lager - Intl / Vienna
#          </option>
#          <option value="/beerstyles/apple-cider/10/">
#           Apple Cider
#          </option>
#          <option value="/beerstyles/apple-cider-flavored/171/">
#           Apple Cider - Flavored
#          </option>
#          <option value="/beerstyles/apple-cider-hopped/172/">
#           Apple Cider - Hopped
#          </option>
#          <option value="/beerstyles/apple-cider-ice-fire-fortified/112/">
#           Apple Cider-Ice/Fire/Fortified
#          </option>
#          <option value="/beerstyles/barleywine-wheatwine-ryewine/11/">
#           BarleyWine / WheatWine / RyeWine
#          </option>
#          <option value="/beerstyles/belgian-ale-dark-amber/128/">
#           Belgian Ale - Dark / Amber
#          </option>
#          <option value="/beerstyles/belgian-ale-pale-golden/12/">
#           Belgian Ale - Pale / Golden
#          </option>
#          <option value="/beerstyles/belgian-ale-strong-dark/129/">
#           Belgian Ale - Strong Dark
#          </option>
#          <option value="/beerstyles/belgian-ale-strong-pale/13/">
#           Belgian Ale - Strong Pale
#          </option>
#          <option value="/beerstyles/berliner-weisse/61/">
#           Berliner Weisse
# ...
#          </option>
#          <option value="/beer/country/uzbekistan/214/">
#           Uzbekistan
#          </option>
#          <option value="/beer/country/vanuatu/215/">
#           Vanuatu
#          </option>
#          <option value="/beer/country/vatican-city/216/">
#           Vatican City
#          </option>
#          <option value="/beer/country/venezuela/217/">
#           Venezuela
#          </option>
#          <option value="/beer/country/vietnam/218/">
#           Vietnam
#          </option>
#          <option value="/beer/country/wales/239/">
#           Wales
#          </option>
#          <option value="/beer/country/western-sahara/266/">
#           Western Sahara
#          </option>
#          <option value="/beer/country/yemen/248/">
#           Yemen
#          </option>
#          <option value="/beer/country/zambia/222/">
#           Zambia
#          </option>
#          <option value="/beer/country/zimbabwe/223/">
#           Zimbabwe
#          </option>
#         </select>
#        </form>
#        <div style="">
#         <!--<br><a href="/beer/top-50/"><b>Ratebeer Top 50</b></a> overall-->
#         <br/>
#         <a href="http://www.ratebeerbest.com">
#          <img src="/images/logos/rbbest16.png" width="230"/>
#         </a>
#         <br/>
#         <!--a style="text-align:center;" href="http://www.ratebeerbest.com/"><b>RB Best Awards List</b></a-->
#        </div>
#        <style>
#         .shortlist{font-size:13px;text-align:left;}
#        </style>
#        <link href="/css/tags.css" rel="stylesheet" type="text/css"/>
#       </div>
#       <br/>
#       <br/>
#       <div id="tagside">
#        <a href="/tag/showall/">
#         Beer Tags
#        </a>
#       </div>
#       <div style="text-align: left;">
#        <span class="tags">
#         <a href="/tag/collaboration/" style="font-size: 12px;">
#          collaboration
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/citra/" style="font-size: 12px;">
#          citra
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/vanilla/" style="font-size: 12px;">
#          vanilla
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/mosaic/" style="font-size: 12px;">
#          mosaic
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/lactose/" style="font-size: 12px;">
#          lactose
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/oats/" style="font-size: 12px;">
#          oats
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/simcoe/" style="font-size: 12px;">
#          simcoe
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/barrel-aged/" style="font-size: 12px;">
#          barrel aged
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/galaxy/" style="font-size: 12px;">
#          galaxy
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/coffee/" style="font-size: 12px;">
#          coffee
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cascade/" style="font-size: 12px;">
#          cascade
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/amarillo/" style="font-size: 12px;">
#          amarillo
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/dry-hopped/" style="font-size: 12px;">
#          dry hopped
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/canned/" style="font-size: 12px;">
#          canned
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/nelson-sauvin/" style="font-size: 12px;">
#          nelson sauvin
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cacao-nibs/" style="font-size: 12px;">
#          cacao nibs
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/gluten-free/" style="font-size: 12px;">
#          gluten free
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/columbus/" style="font-size: 12px;">
#          columbus
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/bourbon-ba/" style="font-size: 12px;">
#          bourbon ba
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/sabro/" style="font-size: 12px;">
#          sabro
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/single-hop/" style="font-size: 12px;">
#          single hop
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/triple-ipa/" style="font-size: 12px;">
#          triple ipa
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/sugar/" style="font-size: 12px;">
#          sugar
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/chinook/" style="font-size: 12px;">
#          chinook
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/wheat/" style="font-size: 12px;">
#          wheat
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/white-stout/" style="font-size: 12px;">
#          white stout
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/whiskey-ba/" style="font-size: 12px;">
#          whiskey ba
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/cinnamon/" style="font-size: 12px;">
#          cinnamon
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/chocolate/" style="font-size: 12px;">
#          chocolate
#         </a>
#        </span>
#        <span class="tags">
#         <a href="/tag/coconut/" style="font-size: 12px;">
#          coconut
#         </a>
#        </span>
#        <a class="btn btn-sm btn-warning" href="/tag/showall/">
#         show all
#        </a>
#       </div>
#       <br/>
#       <br/>
#       <div 1.75;"="" line-height:="" style="style=">
#        <div id="tagside">
#         More Lists
#        </div>
#        <a href="/top">
#         Customizable Top 50
#        </a>
#        <br/>
#        <a href="/beer/top-50-beer-gods/">
#         Beer Gods' Top 50 Beers
#        </a>
#        <br/>
#        <a href="/Ratings/TopAccessible.asp">
#         Top Widely Distributed Beers
#        </a>
#        <br/>
#        <a href="/Ratings/BigNewBeers.asp">
#         Top Big New Beers
#        </a>
#        <br/>
#        <a href="/Ratings/TopSeasonals.asp">
#         Top Seasonal Beers
#        </a>
#        <br/>
#        <a href="/Ratings/Top90Days.asp">
#         The Last 90 Days
#        </a>
#        <br/>
#        <span class="premie">
#         P
#        </span>
#        <a href="/Ratings/Top50Retired.asp">
#         Top 50 Retired Beers
#        </a>
#        <br/>
#        <a href="/Ratings/MakeOrBreak.asp">
#         Make It Or Break It
#        </a>
#        <br/>
#        <a href="/Ratings/newgood.asp">
#         Top Newly Listed Beers
#        </a>
#        <br/>
#        <a href="/Ratings/topstrong.asp">
#         Top Strong Beers
#        </a>
#        <br/>
#        <a href="/ratings/most-difficult-countries/">
#         Most Difficult Countries to Drink
#        </a>
#        <br/>
#        <br/>
#        <a href="/Ratings/TopSakes.asp">
#         Top Sake
#        </a>
#        <br/>
#        <a href="/Ratings/TopMeads.asp">
#         Top Mead
#        </a>
#        <br/>
#        <a href="/Ratings/TheWorstBeers.asp">
#         The Worst Beers In The World
#        </a>
#        <br/>
#        <br/>
#        <div id="tagside">
#         Even More Lists
#        </div>
#        <a href="/Ratings/MostActiveBrewers.asp">
#         The Most Active Brewers
#        </a>
#        <br/>
#        <a href="/Ratings/TopAlcohol.asp">
#         The Strongest Beers In The World
#        </a>
#        <br/>
#        <a href="/Ratings/TopUltralights.asp">
#         Top Session Strength
#        </a>
#        <br/>
#        <a href="/Ratings/TopWeekly.asp">
#         The Top Weekly
#        </a>
#        <br/>
#        <a href="/Ratings/TopIBU.asp">
#         The Top IBU
#        </a>
#        <br/>
#        <a href="/Ratings/TopOfTheMonth.asp">
#         Top Beers of the Month
#        </a>
#        <br/>
#        <span class="premie">
#         P
#        </span>
#        <a href="/Ratings/TopMostWanted.asp">
#         The Most Wanted Beers
#        </a>
#        <br/>
#        <a href="/NewBeers.asp">
#         Newest Beers
#        </a>
#        <br/>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#   <br/>
#   <br/>
#   <!--=== Footer ===-->
#   <br/>
#   <br/>
#   <div class="footer">
#    <div class="container" style="border-top: 1px solid #e0e0e0">
#     <br/>
#     <br/>
#     <div class="clearfix">
#      <div class="col-md-4 md-margin-bottom-40">
#       <!-- About -->
#       <img alt="ratebeer logo" src="/images/logos/rbfooter2.png" width="131"/>
#       <br/>
#       <br/>
#       <h4>
#        Contact us
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/about">
#         About Us
#        </a>
#        <br/>
#        <a href="/faq">
#         Frequently Asked Questions
#        </a>
#        <br/>
#        <a href="/feedback">
#         Feedback
#        </a>
#        <br/>
#        <br/>
#        <a href="https://play.google.com/store/apps/details?id=com.ratebeer&amp;utm_source=RateBeer&amp;utm_medium=footer&amp;utm_campaign=public_launch">
#         <img alt="Get it on Google Play" src="https://play.google.com/intl/en_us/badges/images/generic/en_badge_web_generic.png" style="width:168px;"/>
#        </a>
#        <br/>
#        <a href="https://itunes.apple.com/us/app/keynote/id1221018606?mt=8&amp;utm_source=RateBeer&amp;utm_medium=footer&amp;utm_campaign=public_launch">
#         <img alt="Get it on the App Store" src="/images/App_Store_Badge_US-UK_135x40.svg" style="padding: 10px; width: 170px;"/>
#        </a>
#       </p>
#       <!-- End About -->
#       <br/>
#       <!-- End Monthly Newsletter -->
#      </div>
#      <!--/col-md-4-->
#      <div class="col-md-4 md-margin-bottom-40">
#       <h4>
#        Add To RateBeer
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/add-beer">
#         Add A Beer
#        </a>
#        <br/>
#        <a href="/add-brewer">
#         Add A Brewer
#        </a>
#        <br/>
#        <a href="/add-place">
#         Add A Place
#        </a>
#        <br/>
#        <a href="/add-event">
#         Add An Event
#        </a>
#       </p>
#       <br/>
#       <h4>
#        Manage Your Account
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="/AboutPremium_Join.asp">
#         Add Premium
#        </a>
#        <br/>
#        <a href="/EditUser.asp">
#         Edit Profile
#        </a>
#        <br/>
#        <a href="/Messages.asp">
#         Messages
#        </a>
#        <br/>
#        <a href="/signout.asp">
#         Sign out
#        </a>
#        <br/>
#       </p>
#      </div>
#      <!--/col-md-4-->
#      <div class="col-md-4">
#       <!-- Monthly Newsletter -->
#       <h4>
#        RateBeer Newsletter
#       </h4>
#       <p>
#        Subscribe to our newsletter, RateBeer Weekly, a must for understanding new people, places and beers in worldwide craft culture.
#       </p>
#       <div id="mc_embed_signup">
#        <form action="//ratebeer.us2.list-manage.com/subscribe/post?u=927a170c4a7bc5ac2c11d7a5f&amp;id=33216a9626" class="validate" id="mc-embedded-subscribe-form" method="post" name="mc-embedded-subscribe-form" novalidate="" target="_blank">
#         <div id="mc_embed_signup_scroll">
#          <!--label for="mce-EMAIL">Subscribe to our mailing list</label-->
#          <input class="form-control" id="mce-EMAIL" name="EMAIL" placeholder="email address" required="" type="email" value=""/>
#          <!-- real people should not fill this in and expect good things - do not remove this or risk form bot signups-->
#          <div style="position: absolute; left: -5000px;">
#           <input name="b_927a170c4a7bc5ac2c11d7a5f_33216a9626" tabindex="-1" type="text" value=""/>
#          </div>
#          <div class="clear">
#           <input class="btn btn-primary" id="mc-embedded-subscribe" name="subscribe" style="margin-top: 5px;" type="submit" value="Subscribe"/>
#          </div>
#         </div>
#        </form>
#       </div>
#       <!--End mc_embed_signup-->
#       <!-- End Social Links -->
#       <br/>
#       <!-- Social Links -->
#       <h4>
#        Stay Connected
#       </h4>
#       <p class="margin-bottom-25 md-margin-bottom-40">
#        <a href="https://www.facebook.com/pages/RateBeer/153277718016808">
#         <i class="fa fa-facebook-square fa-3x social-fb" id="social">
#         </i>
#        </a>
#        <a href="https://twitter.com/ratebeer">
#         <i class="fa fa-twitter-square fa-3x social-tw" id="social">
#         </i>
#        </a>
#        <a href="https://plus.google.com/112964660796936121915/posts">
#         <i class="fa fa-google-plus-square fa-3x social-gp" id="social">
#         </i>
#        </a>
#        <!--a href="mailto:@ratebeer.com"><i id="social" class="fa fa-envelope-square fa-3x social-em"></i></a-->
#       </p>
#      </div>
#      <!--/col-md-4-->
#     </div>
#    </div>
#   </div>
#   <!--/footer-->
#   <!--=== End Footer ===-->
#   <br/>
#   <br/>
#   <!--=== Copyright ===-->
#   <div class="copyright">
#    <div class="container">
#     <div class="row">
#      <div class="col-md-6">
#       <p>
#        2000-
#           2020 © RateBeer, LLC. All Rights Reserved.
#        <a href="/privacy_policy.asp">
#         Privacy Policy
#        </a>
#        |
#        <a href="/useragreement.asp">
#         Terms of Service
#        </a>
#       </p>
#      </div>
#      <div class="col-md-6">
#       <a href="/">
#        <!--img class="pull-right" id="logo-footer" src="assets/img/logo2-default.png" alt=""-->
#       </a>
#      </div>
#     </div>
#    </div>
#   </div>
#   <!--/copyright-->
#   <!--=== End Copyright ===-->
#   <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
# 	var isLoggedIn =
#
# 	ga('create', 'UA-1881232-1', 'auto');
#
# 	if (isLoggedIn > 0) {
# 		ga('send', {
# 			hitType: 'pageview',
# 			'dimension2': 'LoggedInUser'
# 		});
# 	} else {
# 			ga('send', 'pageview')
# 	}
#   </script>
#   <script src="/js/form-validation.js" type="text/javascript">
#   </script>
#   <script type="text/javascript">
#    var getUrlParameter = function getUrlParameter(sParam) {
#     var sPageURL = decodeURIComponent(window.location.search.substring(1)),
#         sURLVariables = sPageURL.split('&'),
#         sParameterName,
#         i;
#
#     for (i = 0; i < sURLVariables.length; i++) {
#       sParameterName = sURLVariables[i].split('=');
#
#       if (sParameterName[0] === sParam) {
#         return sParameterName[1] === undefined ? true : sParameterName[1];
#       }
#     }
#   };
#   </script>
#   <script src="https://cdn.auth0.com/js/lock/11.3.1/lock.min.js" type="text/javascript">
#   </script>
#   <script src="https://cdn.auth0.com/js/auth0/9.3.3/auth0.min.js">
#   </script>
#   <script src="/js/auth-zero-btn.js" type="text/javascript">
#   </script>
#   <style type="text/css">
#    .auth0-lock.auth0-lock .auth0-lock-submit {
#     background: #0098CD!important;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-input-wrap,
#   .auth0-lock.auth0-lock .auth0-lock-social-button,
#   .auth0-lock.auth0-lock .auth0-lock-cred-pane {
#     border-radius: 12px;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-input-wrap .auth0-lock-input {
#     border-radius: 0 12px 12px 0;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-header {
#     border-radius: 12px 12px 0 0;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-submit {
#     border-radius: 0 0 12px 12px;
#   }
#   #auth0-container {
#     width: 320px;
#     max-height: 498px;
#     margin: 40px auto;
#     padding: 10px;
#     box-sizing: border-box;
#   }
#   .auth0-lock.auth0-lock .auth0-lock-header-logo {
#     height: 92px;
#   }
#   .auth0-lock-name {
#     display:none;
#   }
#   </style>
#   <script type="text/javascript">
#    window.userIsLoggedIn=false;
#   </script>
#   <!-- defer redirects -->
#   <script type="text/javascript">
#    $('[defer-redirect]').on('click', function (event) {
#     if (!window.userIsLoggedIn) {
#       event.preventDefault();
# 	  Auth0.signin();
#     }
#   });
#   </script>
#  </body>
# </html>

# %%
recent_url = 'http://www.ratebeer.com/beer-ratings/0/' # 'most recent' review page
count = 1
while count < 5:                    #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# http://www.ratebeer.com/beer-ratings/0/2/
# http://www.ratebeer.com/beer-ratings/0/3/
# http://www.ratebeer.com/beer-ratings/0/4/

# %%
# set 'count < 100' to return all pages 
beers = []
recent_url = 'http://www.ratebeer.com/beer-ratings/0/' # 'most recent' review page
count = 1
while count < 5:                    #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages (returns 1st 4)
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url) #comment out if you dont want to see all the lines printed

    page = requests.get(new_url, verify=True)
    page.status_code

    soup = BeautifulSoup(page.text, 'html.parser')
    
    name_soup = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
      
    for beer_name in name_soup:
        print(beer_name.text)  
        beers.append(beer_name.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# Dogfish Head American Beauty Hazy Ripple IPA
# Iowa 3rd Street Stout
# Ninkasi Megalodom
# Beck's
# Gigantic Massive! - Cognac Barrel
# Kona Island Colada Cream Ale
# Heineken
# Spring House Taang!
# Pipeworks Donut Soup
# Maine Beer Zoe
# Robinsons Helles Lager Bier
# Kansas Avenue Ghostly Coyote
# Bell's Light Hearted Ale
# Torrside Autonomy
# Pentrich Mild Chaos
# http://www.ratebeer.com/beer-ratings/0/2/
# Neptune Baltic
# 14er Double Mt Massive IPA
# Foothills Frostbite Black IPA
# Four Mile Allegheny IPA
# Blackberry Farm Abbey Series - Quad
# Soulcraft All Mountain Amber
# Rhinegeist Oddjob
# Barrel Theory Full Send
# Weathered Souls Kicked Out The Waffle House
# Flossmoor Station Kratos Imperial Stout - Barrel Aged
# Bellwoods White Picket Fence (Peach)
# Great North Hazy Rotation - Batch Six - Citra/Mosaic
# Two Pitchers Nordic Jam
# Two Pitchers Nordic Jam
# Bays Gold
# http://www.ratebeer.com/beer-ratings/0/3/
# De Dolle Stille Nacht
# Worthy Lights Out Stout
# Cerveza Zulia
# Firebrand Yakima Session Red
# High Water West Meets East
# Worthy Pyroclastic Flow
# Exmoor Beast (Cask)
# Worthy Strata IPA
# Tonewood Midnight Marauder
# Cotleigh Buzzard
# FrauGruber / Dry & Bitter Slaves Of Convenience
# Worthy Subatomic
# Krombacher Pils
# Samuel Smiths Organic  Apricot  Fruit Beer
# Helltown lawful evil
# http://www.ratebeer.com/beer-ratings/0/4/
# Worthy Worthy and Wise
# Pipe Dream CT Crunch Stout
# Worthy Sol Power Pils
# Budweiser
# Track 7 Poor Pitiful Me
# Chaos Mountain Squatch Ale
# Contrary Oak Syvyys
# Pressure Drop Slumber
# Salcombe Pale Ale
# Great Newsome Pricky Back Otchan
# Singlecut Eric More Cowbell! Chocolate Milk Stout
# Contrary Life After Breakfast Smoked Maple Coffee Porter
# Right Proper Häxan (2015-present)
# Sixpoint Party Hat
# Contrary Punch You In The Eye

# %%
print(beers) #now we have a list of all the names of the beer from recents tab
# Out:
# ['Dogfish Head American Beauty Hazy Ripple IPA', 'Iowa 3rd Street Stout', 'Ninkasi Megalodom', "Beck's", 'Gigantic Massive! - Cognac Barrel', 'Kona Island Colada Cream Ale', 'Heineken', 'Spring House Taang! ', 'Pipeworks Donut Soup', 'Maine Beer Zoe', 'Robinsons Helles Lager Bier', 'Kansas Avenue Ghostly Coyote', "Bell's Light Hearted Ale", 'Torrside Autonomy', 'Pentrich Mild Chaos', 'Neptune Baltic', '14er Double Mt Massive IPA', 'Foothills Frostbite Black IPA', 'Four Mile Allegheny IPA', 'Blackberry Farm Abbey Series - Quad', 'Soulcraft All Mountain Amber', 'Rhinegeist Oddjob', 'Barrel Theory Full Send', 'Weathered Souls Kicked Out The Waffle House', 'Flossmoor Station Kratos Imperial Stout - Barrel Aged', 'Bellwoods White Picket Fence (Peach)', 'Great North Hazy Rotation - Batch Six - Citra/Mosaic', 'Two Pitchers Nordic Jam', 'Two Pitchers Nordic Jam', 'Bays Gold', 'De Dolle Stille Nacht', 'Worthy Lights Out Stout', 'Cerveza Zulia', 'Firebrand Yakima Session Red', 'High Water West Meets East', 'Worthy Pyroclastic Flow', 'Exmoor Beast (Cask)', 'Worthy Strata IPA', 'Tonewood Midnight Marauder ', 'Cotleigh Buzzard ', 'FrauGruber / Dry & Bitter Slaves Of Convenience', 'Worthy Subatomic', 'Krombacher Pils', 'Samuel Smiths Organic  Apricot  Fruit Beer', 'Helltown lawful evil', 'Worthy Worthy and Wise', 'Pipe Dream CT Crunch Stout', 'Worthy Sol Power Pils', 'Budweiser', 'Track 7 Poor Pitiful Me', 'Chaos Mountain Squatch Ale', 'Contrary Oak Syvyys', 'Pressure Drop Slumber', 'Salcombe Pale Ale ', 'Great Newsome Pricky Back Otchan', 'Singlecut Eric More Cowbell! Chocolate Milk Stout', 'Contrary Life After Breakfast Smoked Maple Coffee Porter', 'Right Proper Häxan (2015-present)', 'Sixpoint Party Hat', 'Contrary Punch You In The Eye']

# %%
# from 'most recent' reviews page
beer_ratings = []
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
count = 1
while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)

    page = requests.get(new_url, verify=True)
    page.status_code

    soup = BeautifulSoup(page.text, 'html.parser')
    
    rating_soup = soup.findAll('span', attrs={'class':'uas'})
    
    for beer_rating in rating_soup:
        if beer_rating.text == '\xa0':
            pass
        else:
            print(beer_rating.text)
            beer_ratings.append(beer_rating.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# 3.3
# 3.6
# 2.9
# 2.1
# 4.2
# 3.8
# 1.3
# 3.7
# 4.0
# 4.1
# 2.5
# 2.9
# 4.2
# 2.8
# 2.9
# http://www.ratebeer.com/beer-ratings/0/2/
# 3.5
# 3.4
# 3.8
# 3.5
# 3.7
# 3.4
# 3.1
# 3.2
# 4.4
# 4.3
# 4.0
# 3.7
# 3.6
# 3.4
# 3.2
# http://www.ratebeer.com/beer-ratings/0/3/
# 4.7
# 3.6
# 2.0
# 2.9
# 5.0
# 3.6
# 4.1
# 3.4
# 3.9
# 4.0
# 3.4
# 3.2
# 3.0
# 3.7
# 3.8
# http://www.ratebeer.com/beer-ratings/0/4/
# 3.4
# 3.5
# 3.4
# 2.5
# 3.9
# 3.7
# 4.0
# 3.8
# 3.3
# 3.1
# 4.0
# 4.2
# 3.4
# 3.5
# 3.7

# %%
print(beer_ratings)
# Out:
# ['3.3', '3.6', '2.9', '2.1', '4.2', '3.8', '1.3', '3.7', '4.0', '4.1', '2.5', '2.9', '4.2', '2.8', '2.9', '3.5', '3.4', '3.8', '3.5', '3.7', '3.4', '3.1', '3.2', '4.4', '4.3', '4.0', '3.7', '3.6', '3.4', '3.2', '4.7', '3.6', '2.0', '2.9', '5.0', '3.6', '4.1', '3.4', '3.9', '4.0', '3.4', '3.2', '3.0', '3.7', '3.8', '3.4', '3.5', '3.4', '2.5', '3.9', '3.7', '4.0', '3.8', '3.3', '3.1', '4.0', '4.2', '3.4', '3.5', '3.7']

# %%
# Using naive method
name_rating = {}
for key in beers:
    for value in beer_ratings:
        name_rating[key] = value
        beer_ratings.remove(value)
        break

# %%
print(name_rating)
# Out:
# {'Dogfish Head American Beauty Hazy Ripple IPA': '3.3', 'Iowa 3rd Street Stout': '3.6', 'Ninkasi Megalodom': '2.9', "Beck's": '2.1', 'Gigantic Massive! - Cognac Barrel': '4.2', 'Kona Island Colada Cream Ale': '3.8', 'Heineken': '1.3', 'Spring House Taang! ': '3.7', 'Pipeworks Donut Soup': '4.0', 'Maine Beer Zoe': '4.1', 'Robinsons Helles Lager Bier': '2.5', 'Kansas Avenue Ghostly Coyote': '2.9', "Bell's Light Hearted Ale": '4.2', 'Torrside Autonomy': '2.8', 'Pentrich Mild Chaos': '2.9', 'Neptune Baltic': '3.5', '14er Double Mt Massive IPA': '3.4', 'Foothills Frostbite Black IPA': '3.8', 'Four Mile Allegheny IPA': '3.5', 'Blackberry Farm Abbey Series - Quad': '3.7', 'Soulcraft All Mountain Amber': '3.4', 'Rhinegeist Oddjob': '3.1', 'Barrel Theory Full Send': '3.2', 'Weathered Souls Kicked Out The Waffle House': '4.4', 'Flossmoor Station Kratos Imperial Stout - Barrel Aged': '4.3', 'Bellwoods White Picket Fence (Peach)': '4.0', 'Great North Hazy Rotation - Batch Six - Citra/Mosaic': '3.7', 'Two Pitchers Nordic Jam': '3.4', 'Bays Gold': '3.2', 'De Dolle Stille Nacht': '4.7', 'Worthy Lights Out Stout': '3.6', 'Cerveza Zulia': '2.0', 'Firebrand Yakima Session Red': '2.9', 'High Water West Meets East': '5.0', 'Worthy Pyroclastic Flow': '3.6', 'Exmoor Beast (Cask)': '4.1', 'Worthy Strata IPA': '3.4', 'Tonewood Midnight Marauder ': '3.9', 'Cotleigh Buzzard ': '4.0', 'FrauGruber / Dry & Bitter Slaves Of Convenience': '3.4', 'Worthy Subatomic': '3.2', 'Krombacher Pils': '3.0', 'Samuel Smiths Organic  Apricot  Fruit Beer': '3.7', 'Helltown lawful evil': '3.8', 'Worthy Worthy and Wise': '3.4', 'Pipe Dream CT Crunch Stout': '3.5', 'Worthy Sol Power Pils': '3.4', 'Budweiser': '2.5', 'Track 7 Poor Pitiful Me': '3.9', 'Chaos Mountain Squatch Ale': '3.7', 'Contrary Oak Syvyys': '4.0', 'Pressure Drop Slumber': '3.8', 'Salcombe Pale Ale ': '3.3', 'Great Newsome Pricky Back Otchan': '3.1', 'Singlecut Eric More Cowbell! Chocolate Milk Stout': '4.0', 'Contrary Life After Breakfast Smoked Maple Coffee Porter': '4.2', 'Right Proper Häxan (2015-present)': '3.4', 'Sixpoint Party Hat': '3.5', 'Contrary Punch You In The Eye': '3.7'}

# %%
# from 'most recent' reviews page
reviews = []
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
count = 1
while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)

    page = requests.get(new_url, verify=True)
    page.status_code

    soup = BeautifulSoup(page.text, 'html.parser')
    
    review_soup = soup.findAll('div', {'style':'color:#666;'})
    
    for review in review_soup:
            print(review.text)
            reviews.append(review.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# On Tap.  Classic hazy light golden straw color. Soft wheaty floral, tropical aromas and fa=lavors.  Flowery even.  Soft pillowy finish.  A littel allspice or clove at the end. A bit fancy and pretentious but pleasant and soft.
# 12oz can from Windsor Hy-Vee, in a Sam Smith pint glass. Aromas of vanilla, caramel, malted barley, wet grass, forest floor, milk chocolate and dark-roast coffee. Pours deep chocolate brown with one finger of foamy chocolate head that dissipates rapidly. Opens crisp and acidic for its style with creamy sweet roast taking charge on the mid-palate and a long roasty and somewhat hoppy finish. Medium- to full-bodied with mild stickiness and astringency in the end, just a touch. Not bad! Nose is very appealing, flavor is a bit generic, but the price is great and it's very drinkable.
# On Tap  Clear medium golden with a  lasting dense white head. Strang clean hard biting piney and somewhat chemically hop bitterness.   Clean dry finish
# My old man's go to. Very important to get the imported variant rather than the domestically brewed stuff. Although, it's not really that great and I'd have a few choices over it at the price point. A bit bolder than the regular macro lager, but otherwise quite standard.
# Bottle from Bine & Vine. Pours hazy ruddy brown with a slight beige head. Aroma of slight musty oak and brandy. Note: This should also be placed in Calvados barrels. There's medium dark fruit notes. Can't parse out malt. There is heat mixed in the aroma. Full bodied. Flavor is musty oak, brandy, red berries, roasty malt, brown sugar. Heat is detectable, but so subtle it has to be paid attention to - cause the overall flavors really obscure it. Not dry, but something, perhaps heat, tends to balance out the malt. This is excellent.
# Can smell the cream, pineapple and some coconut. Get mostly cream and some sweet pineapple. Decent.
# Another lame macro lager. Boring and watery. I don't know why people bother to import this into Australia when there are a billion beers like it already available.
# 16 oz. Aroma is Smarties, Tang, oranges, bready. Pours hazy golden with large-ish chunks of sediment floating around; has a one finger bone-white head with decent retention. Taste has a moderate pithy  bitterness, a light to moderate sweetness, with flavors of Tang and oranges, peel and pulp, vanilla. Not bad.
# 16 ounce can.  Pours black with a decent tan head.  Aroma of chocolate, malt, vanilla, and coconut.  Taste is chocolate, vanilla, coconut, roasted malt, and a bit of coffee.  Nice to sip on.
# 500 ml. bottled 10/29/2019. Slightly foggy, chestnut brew with a creamy film of foam. Interesting aroma of pineapple upside-down cake with touches of cocoa, grapefruit and orange. Flavor has bread, orange, grapefruit, toffee, white pepper, toasted walnut and a touch of coffee. Medium body has medium-high carbonation that's almost too much but remains smooth enough. Easy drinking balance that finishes nutty and dry.
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
count = 1
while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)

    page = requests.get(new_url, verify=True)
    page.status_code

    soup = BeautifulSoup(page.text, 'html.parser')
    
    location_soup = soup.findAll('span', {'class': 'small'})
    
    for location in location_soup:
            print(location.text)
            locations.append(location.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# Milton, Delaware
# Cedar Rapids, Iowa
# Eugene, Oregon
# Bremen, Bremen
# Portland, Oregon
# Kailua Kona, Hawaii
# Zoeterwoude, Netherlands
# Conestoga, Pennsylvania
# Chicago, Illinois
# Freeport, Maine
# Stockport, Greater Manchester
# Salford, Greater Manchester
# Comstock, Michigan
# New Mills, Derbyshire
# Pentrich, Derbyshire
# http://www.ratebeer.com/beer-ratings/0/2/
# Liverpool, Merseyside
# Denver, Colorado
# Winston-Salem, North Carolina
# Olean, New York
# Walland, Tennessee
# Salida, Colorado
# Cincinnati, Ohio
# St Paul, Minnesota
# San Antonio, Texas
# Flossmoor, Illinois
# Toronto, Ontario
# Manchester , New Hampshire
# San Francisco, California
# San Francisco, California
# Paignton, Devon
# http://www.ratebeer.com/beer-ratings/0/3/
# Diksmuide, Belgium
# Bend, Oregon
# , Venezuela
# Launceston, Cornwall
# Chico, California
# Bend, Oregon
# Wiveliscombe, Somerset
# Bend, Oregon
# Oaklyn, New Jersey
# Wiveliscombe, Somerset
# Gundelfingen , Bavaria
# Bend, Oregon
# Kreuztal-Krombach, North Rhine-Westphalia
# Tadcaster, North Yorkshire
# Mount Pleasant, Pennsylvania
# http://www.ratebeer.com/beer-ratings/0/4/
# Bend, Oregon
# Londonderry , New Hampshire
# Bend, Oregon
# St. Louis, Missouri
# Sacramento, California
# Callaway, Virginia
# Muscatine, Iowa
# Tottenham Hale, Greater London
# Kingsbridge, Devon
# Hull, East Yorkshire
# Queens, New York
# Muscatine, Iowa
# Washington, Washington DC
# Brooklyn, New York
# Muscatine, Iowa

# %%
print(locations)
# Out:
# ['Milton, Delaware                         ', 'Cedar Rapids, Iowa                             ', 'Eugene, Oregon                           ', 'Bremen, Bremen                           ', 'Portland, Oregon                           ', 'Kailua Kona, Hawaii                           ', 'Zoeterwoude, Netherlands                      ', 'Conestoga, Pennsylvania                     ', 'Chicago, Illinois                         ', 'Freeport, Maine                            ', 'Stockport, Greater Manchester               ', 'Salford, Greater Manchester               ', 'Comstock, Michigan                         ', 'New Mills, Derbyshire                       ', 'Pentrich, Derbyshire                       ', 'Liverpool, Merseyside                       ', 'Denver, Colorado                         ', 'Winston-Salem, North Carolina                   ', 'Olean, New York                         ', 'Walland, Tennessee                        ', 'Salida, Colorado                         ', 'Cincinnati, Ohio                             ', 'St Paul, Minnesota                        ', 'San Antonio, Texas                            ', 'Flossmoor, Illinois                         ', 'Toronto, Ontario                          ', 'Manchester , New Hampshire                    ', 'San Francisco, California                       ', 'San Francisco, California                       ', 'Paignton, Devon                            ', 'Diksmuide, Belgium                          ', 'Bend, Oregon                           ', ', Venezuela                        ', 'Launceston, Cornwall                         ', 'Chico, California                       ', 'Bend, Oregon                           ', 'Wiveliscombe, Somerset                         ', 'Bend, Oregon                           ', 'Oaklyn, New Jersey                       ', 'Wiveliscombe, Somerset                         ', 'Gundelfingen , Bavaria                          ', 'Bend, Oregon                           ', 'Kreuztal-Krombach, North Rhine-Westphalia           ', 'Tadcaster, North Yorkshire                  ', 'Mount Pleasant, Pennsylvania                     ', 'Bend, Oregon                           ', 'Londonderry , New Hampshire                    ', 'Bend, Oregon                           ', 'St. Louis, Missouri                         ', 'Sacramento, California                       ', 'Callaway, Virginia                         ', 'Muscatine, Iowa                             ', 'Tottenham Hale, Greater London                   ', 'Kingsbridge, Devon                            ', 'Hull, East Yorkshire                   ', 'Queens, New York                         ', 'Muscatine, Iowa                             ', 'Washington, Washington DC                    ', 'Brooklyn, New York                         ', 'Muscatine, Iowa                             ']

# %%
# from 'most recent' reviews page
users = []
recent_url = 'http://www.ratebeer.com/beer-ratings/0/'
count = 1
while count < 5:                  #=|>>>>>>>>>>  change the 'count < 5' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)

    page = requests.get(new_url, verify=True)
    page.status_code

    soup = BeautifulSoup(page.text, 'html.parser')
    
    user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
    for user in user_soup[1::2]:
            print(user.text)
#             users.append(user.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# IndianaRed
# saltyseadog
# IndianaRed
# fellers
# bhensonb
# Obfuscate
# fellers
# poisoneddwarf
# RobertDale
# nearbeer
# ManVsBeer
# ManVsBeer
# Obfuscate
# ManVsBeer
# ManVsBeer
# http://www.ratebeer.com/beer-ratings/0/2/
# ManVsBeer
# ManVsBeer
# drjay44
# eRock_2013
# FROMTHEBOTTLE
# Idiosynkrasie
# Kleg
# jsporrer
# deyholla
# marcus
# jsquire
# captain-wiggles
# johnnnniee
# HourGlass13
# freekyp
# http://www.ratebeer.com/beer-ratings/0/3/
# moatemalt
# sakimori
# BeerandBlues2
# AlfredoGarcia
# moatemalt
# dflb
# BeerandBlues2
# moatemalt
# BeerandBlues2
# PhillyCraft
# moatemalt
# ogivlado
# BeerandBlues2
# moatemalt
# coil
# http://www.ratebeer.com/beer-ratings/0/4/
# MattShizzle
# BeerandBlues2
# GregMooreNH
# BeerandBlues2
# PubMeister30
# marcus
# nearbeer
# ajnepple
# Beese
# moatemalt
# berkshirejohn
# tekstr1der
# ajnepple
# Maverick34
# williamstome

# %%
# Combined scrape from 'most recent' reviews page

beers = []
ratings = []
locations = []
reviews = []
users = []

recent_url = 'http://www.ratebeer.com/beer-ratings/0/'

count = 1
while count < 2:                  #=|>>>>>>>>>>  change the 'count < x' to increase scrape up to 100 pages
    new_url = (f'{recent_url}{count}/')
    count +=1
    print(new_url)

    page = requests.get(new_url, verify=True)
    page.status_code

#   make a nice soup 
    soup = BeautifulSoup(page.text, 'html.parser')
    
    print("Beer Names: ")
                  
#   beer names scrape        
    name_soup = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
      
    for beer_name in name_soup:
        print(beer_name.text)  
        beers.append(beer_name.text)
        
    print("Beer Ratings: ")
        
#   ratings scrape
    rating_soup = soup.findAll('span', attrs={'class':'uas'})
    
    for beer_rating in rating_soup:
        if beer_rating.text == '\xa0':
            pass
        else:
            print(beer_rating.text)
            ratings.append(beer_rating.text)
    
    print("Brewery Locations: ")
#   location scrape
    location_soup = soup.findAll('span', {'class': 'small'})
    
    for location in location_soup:
            print(location.text)
            locations.append(location.text)
            
    print("User Reviews: ")
    
#   review scrape
    review_soup = soup.findAll('div', {'style':'color:#666;'})
    
    for review in review_soup:
            print(review.text)
            reviews.append(review.text)
            
    print("User Names: ")
    
#   user scrape
    user_soup = soup.findAll('span', {'style':'color:#8b8b8b;'})
    
    for user in user_soup[1::2]:
            print(user.text)
            users.append(user.text)
# Out:
# http://www.ratebeer.com/beer-ratings/0/1/
# Beer Names:
# Notch Kolsch
# Dogfish Head American Beauty Hazy Ripple IPA
# Iowa 3rd Street Stout
# Ninkasi Megalodom
# Beck's
# Gigantic Massive! - Cognac Barrel
# Kona Island Colada Cream Ale
# Heineken
# Spring House Taang!
# Pipeworks Donut Soup
# Maine Beer Zoe
# Robinsons Helles Lager Bier
# Kansas Avenue Ghostly Coyote
# Bell's Light Hearted Ale
# Torrside Autonomy
# Beer Ratings:
# 3.4
# 3.3
# 3.6
# 2.9
# 2.1
# 4.2
# 3.8
# 1.3
# 3.7
# 4.0
# 4.1
# 2.5
# 2.9
# 4.2
# 2.8
# Brewery Locations:
# Salem , Massachusetts
# Milton, Delaware
# Cedar Rapids, Iowa
# Eugene, Oregon
# Bremen, Bremen
# Portland, Oregon
# Kailua Kona, Hawaii
# Zoeterwoude, Netherlands
# Conestoga, Pennsylvania
# Chicago, Illinois
# Freeport, Maine
# Stockport, Greater Manchester
# Salford, Greater Manchester
# Comstock, Michigan
# New Mills, Derbyshire
# User Reviews:
# Pours pale gold into a stange. Bright white head with medium retention recedes to coat surface. Caramel and hay aromas. Soft with hay, grass and sourdough upfront turning to lemon/lime (?!) in the medium length finish.
# On Tap.  Classic hazy light golden straw color. Soft wheaty floral, tropical aromas and fa=lavors.  Flowery even.  Soft pillowy finish.  A littel allspice or clove at the end. A bit fancy and pretentious but pleasant and soft.
# 12oz can from Windsor Hy-Vee, in a Sam Smith pint glass. Aromas of vanilla, caramel, malted barley, wet grass, forest floor, milk chocolate and dark-roast coffee. Pours deep chocolate brown with one finger of foamy chocolate head that dissipates rapidly. Opens crisp and acidic for its style with creamy sweet roast taking charge on the mid-palate and a long roasty and somewhat hoppy finish. Medium- to full-bodied with mild stickiness and astringency in the end, just a touch. Not bad! Nose is very appealing, flavor is a bit generic, but the price is great and it's very drinkable.
# On Tap  Clear medium golden with a  lasting dense white head. Strang clean hard biting piney and somewhat chemically hop bitterness.   Clean dry finish
# My old man's go to. Very important to get the imported variant rather than the domestically brewed stuff. Although, it's not really that great and I'd have a few choices over it at the price point. A bit bolder than the regular macro lager, but otherwise quite standard.
# Bottle from Bine & Vine. Pours hazy ruddy brown with a slight beige head. Aroma of slight musty oak and brandy. Note: This should also be placed in Calvados barrels. There's medium dark fruit notes. Can't parse out malt. There is heat mixed in the aroma. Full bodied. Flavor is musty oak, brandy, red berries, roasty malt, brown sugar. Heat is detectable, but so subtle it has to be paid attention to - cause the overall flavors really obscure it. Not dry, but something, perhaps heat, tends to balance out the malt. This is excellent.
# Can smell the cream, pineapple and some coconut. Get mostly cream and some sweet pineapple. Decent.
# Another lame macro lager. Boring and watery. I don't know why people bother to import this into Australia when there are a billion beers like it already available.
# 16 oz. Aroma is Smarties, Tang, oranges, bready. Pours hazy golden with large-ish chunks of sediment floating around; has a one finger bone-white head with decent retention. Taste has a moderate pithy  bitterness, a light to moderate sweetness, with flavors of Tang and oranges, peel and pulp, vanilla. Not bad.
# 16 ounce can.  Pours black with a decent tan head.  Aroma of chocolate, malt, vanilla, and coconut.  Taste is chocolate, vanilla, coconut, roasted malt, and a bit of coffee.  Nice to sip on.
# 500 ml. bottled 10/29/2019. Slightly foggy, chestnut brew with a creamy film of foam. Interesting aroma of pineapple upside-down cake with touches of cocoa, grapefruit and orange. Flavor has bread, orange, grapefruit, toffee, white pepper, toasted walnut and a touch of coffee. Medium body has medium-high carbonation that's almost too much but remains smooth enough. Easy drinking balance that finishes nutty and dry.
# Keg @ Castle Hotel, Manchester.  Golden with a creamy head.  It's certainly styled well and is crisp with a fair carbonation.  This one is for lager lovers only though.
# Cask @ Abel Heywood, Manchester.  Blonde with a creamy head.  It's a very easy textured hoppy ale with some bitterness.
# An excellent example of a style I really enjoy. Light, crisp with a nice hop profile.
# Cask @ Jack In The Box at Mackie Mayor, Manchester.  Copper-red with a small head.  Has a bittered crisp hoppiness, but not that flavoursome.
# User Names:
# GDTRFB
# IndianaRed
# saltyseadog
# IndianaRed
# fellers
# bhensonb
# Obfuscate
# fellers
# poisoneddwarf
# RobertDale
# nearbeer
# ManVsBeer
# ManVsBeer
# Obfuscate
# ManVsBeer

# %%
beer_dict = {}
 
# Add a list:
beer_dict["Beer Name"] = beers
beer_dict["Rating"] = ratings
beer_dict["Location"] = locations
beer_dict["Review"] = reviews
beer_dict["User"] = users

 
# # Add a dictionary:
# my_dict["sub_dict"] = {"key": "value"}
 
# # Add a set:
# my_dict["my_set"] = set([3, 1, 4, 1, 5, 9, 2])
 
# # Add a Tuple as a key and as a value:
# my_dict[(27.9878, 86.9250)] = ("Everest", "Nepal", 8848)
 
# Prove it all worked:
for key, value in beer_dict.items():
  print("Key: {}\nValue: {}\n\n".format(key,value))
# Out:
# Key: Beer Name
# Value: ['Notch Kolsch', 'Dogfish Head American Beauty Hazy Ripple IPA', 'Iowa 3rd Street Stout', 'Ninkasi Megalodom', "Beck's", 'Gigantic Massive! - Cognac Barrel', 'Kona Island Colada Cream Ale', 'Heineken', 'Spring House Taang! ', 'Pipeworks Donut Soup', 'Maine Beer Zoe', 'Robinsons Helles Lager Bier', 'Kansas Avenue Ghostly Coyote', "Bell's Light Hearted Ale", 'Torrside Autonomy']
#
#
# Key: Rating
# Value: ['3.4', '3.3', '3.6', '2.9', '2.1', '4.2', '3.8', '1.3', '3.7', '4.0', '4.1', '2.5', '2.9', '4.2', '2.8']
#
#
# Key: Location
#
#
# Key: User
# Value: ['GDTRFB', 'IndianaRed', 'saltyseadog', 'IndianaRed', 'fellers', 'bhensonb', 'Obfuscate', 'fellers', 'poisoneddwarf', 'RobertDale', 'nearbeer', 'ManVsBeer', 'ManVsBeer', 'Obfuscate', 'ManVsBeer']

# %%
beers =  np.array([beers])
ratings = np.array([ratings])
locations = np.array([locations])
reviews =  np.array([reviews])
users =  np.array([users])

# %%
dataset = pd.DataFrame({'Beer Names':beers[0,:], 'Rating':ratings[0,:], 'Locations':locations[0,:],'Reviews':reviews[0,:], 'Users':users[0,:]})
print(dataset)
# Out:
#                                       Beer Names Rating  \
# 0                                   Notch Kolsch    3.4
# 1   Dogfish Head American Beauty Hazy Ripple IPA    3.3
# 2                          Iowa 3rd Street Stout    3.6
# 3                              Ninkasi Megalodom    2.9
# 4                                         Beck's    2.1
# 5              Gigantic Massive! - Cognac Barrel    4.2
# 6                   Kona Island Colada Cream Ale    3.8
# 7                                       Heineken    1.3
# 8                           Spring House Taang!     3.7
# 9                           Pipeworks Donut Soup    4.0
# 10                                Maine Beer Zoe    4.1
# 11                   Robinsons Helles Lager Bier    2.5
# 12                  Kansas Avenue Ghostly Coyote    2.9
# 13                      Bell's Light Hearted Ale    4.2
# 14                             Torrside Autonomy    2.8
#
#                                           Locations  \
# 0         Salem , Massachusetts
# 1         Milton, Delaware
# 2   Cedar Rapids, Iowa
# 3         Eugene, Oregon
# 4         Bremen, Bremen
# 5       Portland, Oregon
# 6    Kailua Kona, Hawaii
# 7    Zoeterwoude, Netherlands
# 8      Conestoga, Pennsylvania
# 9        Chicago, Illinois
# 10      Freeport, Maine
# 11     Stockport, Greater Manchester
# 12       Salford, Greater Manchester
# 13      Comstock, Michigan
# 14     New Mills, Derbyshire
#
#                                               Reviews          Users
# 0   Pours pale gold into a stange. Bright white he...         GDTRFB
# 1   On Tap.  Classic hazy light golden straw color...     IndianaRed
# 2   12oz can from Windsor Hy-Vee, in a Sam Smith p...    saltyseadog
# 3   On Tap  Clear medium golden with a  lasting de...     IndianaRed
# 4   My old man's go to. Very important to get the ...        fellers
# 5   Bottle from Bine & Vine. Pours hazy ruddy brow...       bhensonb
# 6   Can smell the cream, pineapple and some coconu...      Obfuscate
# 7   Another lame macro lager. Boring and watery. I...        fellers
# 8   16 oz. Aroma is Smarties, Tang, oranges, bread...  poisoneddwarf
# 9   16 ounce can.  Pours black with a decent tan h...     RobertDale
# 10  500 ml. bottled 10/29/2019. Slightly foggy, ch...       nearbeer
# 11  Keg @ Castle Hotel, Manchester.  Golden with a...      ManVsBeer
# 12  Cask @ Abel Heywood, Manchester.  Blonde with ...      ManVsBeer
# 13  An excellent example of a style I really enjoy...      Obfuscate
# 14  Cask @ Jack In The Box at Mackie Mayor, Manche...      ManVsBeer

# %%
dataset.to_csv('ScrapeDF.csv')
