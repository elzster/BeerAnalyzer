# %%
import pandas as pd
import sqlalchemy as sq
import numpy as np 
import requests
import urllib.request
import time
from bs4 import BeautifulSoup 
from pprint import pprint
# Out:
# Error: Error: Activating Python 3.7.3 64-bit ('base': conda) to run Jupyter failed with Error: StdErr from ShellExec, ERROR: The system was unable to find the specified registry key or value.
# The system cannot find the batch label specified - End
# ERROR: The system was unable to find the specified registry key or value.
# The system cannot find the batch label specified - End
# .

# %%
url = 'http://www.ratebeer.com/beer-ratings/'
page = requests.get(url, verify=False)
page.status_code

soup = BeautifulSoup(page.text, 'html.parser')
# Out:
# C:\Users\nidas\Anaconda\lib\site-packages\urllib3\connectionpool.py:847: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning)

# %% [markdown]
# # Beer Name

# %%
base_url = 'http://www.ratebeer.com/beer-ratings/0/'
urls = []
max = 98

for i in range(0, max):
    urls.append(base_url + str(i))
    
print(urls)
# def scrape_url(url):
#     response = requests.get(url)
# #     print(resp)
#     soup = BeautifulSoup(resp.content, "html.parser")
#     div = soup.findAll('div', {'style': 'color:#666;'}
#     return (div.get_text())

# max = 98
# i = 0
# beers =[]
# for i in range(0,max):
# #     i +=1
#     base_url = f'{base_url}{i}/'
#     #     print(new_url)
#     soup.findAll('div')
#     beer_names = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
# #     for beer in beer_names:
# #             print(beer_names.text)
#     beers.append(beer_names)
#     i+=1
# print(len(beer_names)
# pprint(beers)
# Out:
# ['http://www.ratebeer.com/beer-ratings/0/0', 'http://www.ratebeer.com/beer-ratings/0/1', 'http://www.ratebeer.com/beer-ratings/0/2', 'http://www.ratebeer.com/beer-ratings/0/3', 'http://www.ratebeer.com/beer-ratings/0/4', 'http://www.ratebeer.com/beer-ratings/0/5', 'http://www.ratebeer.com/beer-ratings/0/6', 'http://www.ratebeer.com/beer-ratings/0/7', 'http://www.ratebeer.com/beer-ratings/0/8', 'http://www.ratebeer.com/beer-ratings/0/9', 'http://www.ratebeer.com/beer-ratings/0/10', 'http://www.ratebeer.com/beer-ratings/0/11', 'http://www.ratebeer.com/beer-ratings/0/12', 'http://www.ratebeer.com/beer-ratings/0/13', 'http://www.ratebeer.com/beer-ratings/0/14', 'http://www.ratebeer.com/beer-ratings/0/15', 'http://www.ratebeer.com/beer-ratings/0/16', 'http://www.ratebeer.com/beer-ratings/0/17', 'http://www.ratebeer.com/beer-ratings/0/18', 'http://www.ratebeer.com/beer-ratings/0/19', 'http://www.ratebeer.com/beer-ratings/0/20', 'http://www.ratebeer.com/beer-ratings/0/21', 'http://www.rateb
# ...

# %%
# url = url[0]
# #     soup.findAll('div')
# #     beer_names = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
# # #     for beer in beer_names:
# #             print(beer_names.text)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-68d92ca02580> in <module>
# ----> 1 url = url[0]
#       2 #     soup.findAll('div')
#       3 #     beer_names = soup.findAll('a', {'style': 'font-size:20px; font-weight:bold;'})
#       4 # #     for beer in beer_names:
#       5 # #             print(beer_names.text)
#
# NameError: name 'url' is not defined

# %%
beers = []
for url in urls:
    soup.findAll('div')
    beer_rating = soup.findAll('div', {'style': 'color:#666;'})
    beers.append(beer_rating)
pri
# Out:
# [[<div style="color:#666;">Can.
#
# Head is initially small, frothy, brown, mostly diminishing.
# Body is dark brown to black.
#
# Aroma is moderately malty (roasted grain, cocoa powder), lightly hoppy (herbs).
#
# Flavor is moderately sweet, lightly acidic, lightly bitter.
# Finish is lightly to moderately sweet, lightly acidic, lightly to moderately bitter.
#
# Medium body, watery/syrupy texture, lively carbonation.
#
# ...

# %%
max=50
page_number = 0
new_url = url + str(page_number)
for page_number in range(50):
    print(page_number)
    soup.findAll('div')
    breweries_rating_texts = soup.findAll('div', {'style': 'color:#666;'})
    breweries_rating_texts
    for breweries_rating_text in breweries_rating_texts:
        print(str(breweries_rating_text.text))

# %%
'''
url = "http://example.com"
req = requests.get(url, headers)
soup = BeautifulSoup(req.content, 'html.parser')
print(soup.prettify())
'''

# %% [markdown]
# # Beer Text Rating

# %%
for i in range (0,max):
    base_url += str(i+1)
    soup.findAll('div')
    beer_rating = soup.findAll('div', {'style': 'color:#666;'})
    for beer_ratings in beer_rating:
        print(beer_ratings.text)

# %% [markdown]
# # Brewery Name

# %%
for i in range (0,2):
    base_url += str(i+1)
    soup.findAll('a')
    brewery_name = soup.findAll('a', {'href':'/brewers/modern-times-beer/16983/'})
    for brewery_names in brewery_name:
        print(brewery_names.text)

# %% [markdown]
# # Brewery Location

# %%
for i in range (0,max):
    base_url += str(i+1)
    soup.findAll('span')
    brewery_location = soup.findAll('span', {'class': 'small'})
    for brewery_locations in brewery_location:
        print(brewery_locations.text)

# %% [markdown]
# # Beer Number Rating

# %%
for i in range (0,max):
    base_url += str(i+1)
    soup.findAll('span')
    temp = soup.findAll('span', attrs={"class": "uas"})
    beer_number = []
    for beer_numbers in temp:
        try:
#             print(float(beer_numbers.text))
            beer_number.append(float(beer_numbers.text))
        except:
            '' #do nothing
print(beer_number)

# %%
import csv

with open ('filename.csv','w') as file:
    writer=csv.writer(file)
    print(beer_number)
    for row in beer_number:
        writer.writerow([row])

# %%
print(beer_number)
